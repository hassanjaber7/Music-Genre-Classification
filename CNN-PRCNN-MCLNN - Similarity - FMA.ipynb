# %%
import os
import pandas as pd
import librosa
from tqdm import tqdm

METADATA_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/filtered_tracks_metadata.csv'
DATASET_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large'
MIN_SAMPLES = 22050 * 30  # Minimum required samples, e.g., 30 seconds at 22050 Hz

def downsample_tracks(metadata_path, downsample_ratios):
    """
    Downsamples tracks for each genre according to specified ratios in metadata only.

    Parameters:
        metadata_path (str): Path to the custom metadata CSV file.
        downsample_ratios (dict): Dictionary with genres as keys and downsampling factors (0-1) as values.

    Returns:
        DataFrame: Downsampled DataFrame of tracks.
    """
    # Load the metadata file
    tracks = pd.read_csv(metadata_path, index_col=0)

    # Initialize an empty list to store downsampled DataFrames
    downsampled_dfs = []

    # Loop through each genre and apply downsampling
    for genre, ratio in downsample_ratios.items():
        genre_tracks = tracks[tracks['primary_genre'] == genre]

        # Downsample if ratio < 1, otherwise keep all tracks
        if ratio < 1:
            num_samples = int(len(genre_tracks) * ratio)
            genre_tracks_downsampled = genre_tracks.sample(num_samples, random_state=42)
            print(f"Downsampled {genre} from {len(genre_tracks)} to {len(genre_tracks_downsampled)} tracks")
        else:
            genre_tracks_downsampled = genre_tracks
            print(f"Kept all tracks for {genre} (total: {len(genre_tracks)})")

        downsampled_dfs.append(genre_tracks_downsampled)

    # Combine all downsampled DataFrames
    downsampled_tracks = pd.concat(downsampled_dfs)

    # Display the final count of tracks per genre
    print("\nNumber of tracks per genre after downsampling:")
    print(downsampled_tracks['primary_genre'].value_counts())

    return downsampled_tracks

# Define downsampling ratios for each genre
# downsample_ratios = {
#     'Electronic': 0.078,
#     'Avant-Garde': 0.175,
#     'Experimental': 0.2,
#     'Rock': 0.225,
#     'Pop': 0.26,
#     'Folk': 0.35,
#     'Hip-Hop': 0.37,
#     'Punk': 0.42,
#     'Noise': 0.44,
#     'Lo-Fi': 0.55,
#     'Experimental Pop': 0.55,
#     'Ambient Electronic': 0.74,
#     'Jazz': 0.86,
#     'Classical': 0.90,
#     'International': 0.95,
#     'Blues': 1.0,  # Keep all for Blues
# }
downsample_ratios = {'Rock': 0.0434,
'Folk' :0.044,
'Punk' :0.087,
'Indie-Rock' :0.093,
'Industrial' :0.115,
'Blues' :0.152,
'Post-Rock' :0.169,
'Singer-Songwriter' :0.180832,
'Psych-Folk' :0.188324,
'Psych-Rock' :0.252,
'Freak-Folk' :0.278552,
'Post-Punk' :0.286533,
'Country' :0.339,
'Metal' :0.414938,
'Krautrock' :0.56,
'Noise-Rock' :0.574713,
}




# Perform downsampling
downsampled_tracks = downsample_tracks(METADATA_PATH, downsample_ratios)

# Optional: Save the downsampled data to a new CSV
downsampled_tracks.to_csv('downsampled_tracks_metadata.csv')
# Out:
# Downsampled Rock from 2306 to 100 tracks
# Downsampled Folk from 2288 to 100 tracks
# Downsampled Punk from 1157 to 100 tracks
# Downsampled Indie-Rock from 1086 to 100 tracks
# Downsampled Industrial from 877 to 100 tracks
# Downsampled Blues from 662 to 100 tracks
# Downsampled Post-Rock from 595 to 100 tracks
# Downsampled Singer-Songwriter from 553 to 100 tracks
# Downsampled Psych-Folk from 531 to 100 tracks
# Downsampled Psych-Rock from 397 to 100 tracks
# Downsampled Freak-Folk from 359 to 100 tracks
# Downsampled Post-Punk from 349 to 100 tracks
# Downsampled Country from 295 to 100 tracks
# Downsampled Metal from 241 to 100 tracks
# Downsampled Krautrock from 179 to 100 tracks
# Downsampled Noise-Rock from 174 to 100 tracks
#
# Number of tracks per genre after downsampling:
# primary_genre
# Rock                 100
# Folk                 100
# Punk                 100
# Indie-Rock           100
# Industrial           100
# Blues                100
# Post-Rock            100
# Singer-Songwriter    100
# Psych-Folk           100
# Psych-Rock           100
# Freak-Folk           100
# Post-Punk            100
# Country              100
# Metal                100
# Krautrock            100
# Noise-Rock           100
# Name: count, dtype: int64

# %%
import pandas as pd
import os
import librosa
from tqdm import tqdm

# Paths and settings
METADATA_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_metadata/fma_metadata/custom_tracks_metadata.csv'
DATASET_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large'
MIN_SAMPLES = 12000 * 30  # Set the minimum sample threshold (e.g., 30 seconds at 22050 Hz)

def filter_short_tracks(metadata_path, dataset_path, min_samples):
    """
    Filters out tracks with a sample count less than the specified threshold.

    Parameters:
        metadata_path (str): Path to the metadata CSV file.
        dataset_path (str): Path to the directory with audio files.
        min_samples (int): Minimum number of samples required for a track to be included.

    Returns:
        DataFrame: Filtered DataFrame of tracks.
    """
    # Load metadata
    tracks = pd.read_csv(metadata_path, index_col=0)

    # List to store valid track IDs
    valid_tracks = []

    # Progress bar for filtering
    print("Filtering tracks by minimum sample requirement...")
    for track_id in tqdm(tracks.index, desc="Checking track length"):
        folder = f"{int(track_id):03d}"[:3]  # Folder based on track_id
        file_path = os.path.join(dataset_path, folder, f"{track_id}.mp3")

        if os.path.isfile(file_path):
            try:
                # Load audio file and check length
                signal, _ = librosa.load(file_path, sr=None)
                if len(signal) >= min_samples:
                    valid_tracks.append(track_id)  # Track meets minimum sample requirement
            except Exception as e:
                print(f"Error loading {file_path}: {e}")

    # Filter metadata to include only valid tracks
    filtered_tracks = tracks.loc[valid_tracks]

    # Display the final count of tracks per genre
    print("\nNumber of tracks per genre after filtering:")
    print(filtered_tracks['primary_genre'].value_counts())

    return filtered_tracks

# Apply filtering
filtered_tracks = filter_short_tracks(METADATA_PATH, DATASET_PATH, MIN_SAMPLES)

# Optional: Save the filtered data to a new CSV
filtered_tracks.to_csv('filtered_tracks_metadata.csv')
print("Filtered metadata saved to 'filtered_tracks_metadata.csv'.")
# Out:
# Filtering tracks by minimum sample requirement...
# Checking track length:  64%|████████████████████████████████                  | 23150/36133 [00:00<00:00, 36257.08it/s]C:\Users\HASSAN\AppData\Local\Temp\ipykernel_11548\3680279564.py:38: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, _ = librosa.load(file_path, sr=None)
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\101\101265.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\101\101272.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\101\101275.mp3:
# Checking track length:  67%|██████████████████████████████████▉                 | 24256/36133 [00:20<00:26, 454.45it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\105\105247.mp3:
# Checking track length:  68%|███████████████████████████████████▌                | 24685/36133 [00:40<01:09, 164.38it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\106\106409.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\106\106412.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\106\106415.mp3:
# Checking track length:  70%|████████████████████████████████████▊                | 25114/36133 [01:00<02:15, 81.57it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\108\108920.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\108\108925.mp3:
# Checking track length:  74%|███████████████████████████████████████▎             | 26812/36133 [02:18<06:17, 24.72it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\115\115610.mp3:
# Checking track length:  76%|████████████████████████████████████████▏            | 27383/36133 [02:45<06:32, 22.30it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\117\117441.mp3:
# Checking track length:  82%|███████████████████████████████████████████▌         | 29679/36133 [04:32<05:22, 20.04it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\126\126981.mp3:
# Checking track length:  82%|███████████████████████████████████████████▋         | 29785/36133 [04:38<05:23, 19.63it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\127\127336.mp3:
# Checking track length:  83%|████████████████████████████████████████████▏        | 30151/36133 [04:55<05:08, 19.39it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\129\129207.mp3:
# Checking track length:  84%|████████████████████████████████████████████▋        | 30499/36133 [05:12<04:42, 19.91it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\130\130328.mp3:
# Checking track length:  87%|██████████████████████████████████████████████       | 31374/36133 [05:55<04:13, 18.80it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\133\133641.mp3:
# Checking track length:  87%|██████████████████████████████████████████████       | 31380/36133 [05:55<04:11, 18.90it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\133\133647.mp3:
# Checking track length:  93%|█████████████████████████████████████████████████▍   | 33664/36133 [07:47<02:03, 19.92it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\143\143992.mp3:
# Checking track length:  94%|█████████████████████████████████████████████████▋   | 33846/36133 [07:55<01:54, 19.91it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\145\145056.mp3:
# Checking track length: 100%|████████████████████████████████████████████████████▉| 36060/36133 [09:45<00:03, 19.67it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\155\155051.mp3:
# Checking track length: 100%|█████████████████████████████████████████████████████| 36133/36133 [09:49<00:00, 61.33it/s]
# Number of tracks per genre after filtering:
# primary_genre
# Rock                 2306
# Folk                 2288
# Punk                 1157
# Indie-Rock           1086
# Industrial            877
# Blues                 662
# Post-Rock             595
# Singer-Songwriter     553
# Psych-Folk            531
# Psych-Rock            397
# Freak-Folk            359
# Post-Punk             349
# Country               295
# Metal                 241
# Krautrock             179
# Noise-Rock            174
# Name: count, dtype: int64
# Filtered metadata saved to 'filtered_tracks_metadata.csv'.

# %%
import json
import os
import math
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler

# Paths (same as your original)
DATASET_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large'
METADATA_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/downsampled_tracks_metadata.csv' 
JSON_PATH = "data_fma.json"
SAMPLE_RATE = 12000
TRACK_DURATION = 30  # seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

def print_genre_counts(metadata_path, target_genres=None):
    """Same as your original function"""
    tracks = pd.read_csv(metadata_path, index_col=0)
    if target_genres:
        tracks = tracks[tracks['primary_genre'].isin(target_genres)]
        print(f"Filtered tracks by target genres: {len(tracks)}")
    genre_counts = tracks['primary_genre'].value_counts()
    print("\nNumber of tracks per genre:")
    print(genre_counts)

def load_metadata(metadata_path, dataset_path, target_genres=None):
    """Same as your original function"""
    tracks = pd.read_csv(metadata_path, index_col=0)
    if target_genres:
        tracks = tracks[tracks['primary_genre'].isin(target_genres)]
        print(f"Filtered tracks by target genres: {len(tracks)}")

    available_tracks = set()
    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.endswith('.mp3'):
                track_id = int(os.path.splitext(file)[0])
                available_tracks.add(track_id)

    tracks = tracks[tracks.index.isin(available_tracks)]
    print(f"Tracks after file check: {len(tracks)}")
    return tracks['primary_genre'].dropna()

def save_features(dataset_path, json_path, metadata_path, target_genres, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=10):
    """
    Modified version of your save_mfcc() that includes all features while maintaining the same structure
    """
    data = {
        "mapping": target_genres,
        "labels": [],
        "mfcc": [],          # Keeps same structure as original
        "other_features": [] # New: Stores all other features
    }

    genre_data = load_metadata(metadata_path, dataset_path, target_genres)
    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    with tqdm(total=len(genre_data), desc="Processing files", unit="file") as pbar:
        for track_id, genre in genre_data.items():
            folder = f"{int(track_id):03d}"[:3]
            file_path = os.path.join(dataset_path, folder, f"{track_id}.mp3")
            
            if os.path.isfile(file_path):
                try:
                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                    
                    for d in range(num_segments):
                        start = samples_per_segment * d
                        finish = start + samples_per_segment
                        segment = signal[start:finish]
                        
                        if len(segment) < samples_per_segment:
                            segment = np.pad(segment, (0, samples_per_segment - len(segment)), mode='constant')

                        # Extract MFCCs (same as original)
                        mfcc = librosa.feature.mfcc(y=segment, sr=sample_rate,
                                                  n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T
                        
                        # Extract other features (new)
                        other_features = extract_other_features(segment, sample_rate)
                        
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["other_features"].append(other_features)
                            data["labels"].append(target_genres.index(genre))
                        else:
                            print(f"Skipping segment {d} in {file_path} due to unexpected MFCC shape.")

                    pbar.update(1)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
    print(f"\nFeatures saved to {json_path}")

def extract_other_features(segment, sample_rate):
    """Helper function to extract all non-MFCC features"""
    features = []
    
    # Pitch (Yin algorithm)
    try:
        f0 = librosa.yin(segment, fmin=20, fmax=sample_rate//2)
        f0 = f0[f0 > 0]  # Remove zeros
        features.append(float(np.mean(f0)) if len(f0) > 0 else 0.0)
    except:
        features.append(0.0)
    
    # Tempo
    onset_env = librosa.onset.onset_strength(y=segment, sr=sample_rate)
    tempo, _ = librosa.beat.beat_track(onset_envelope=onset_env, sr=sample_rate)
    features.append(float(tempo))
    
    # Beats (mean interval)
    _, beats = librosa.beat.beat_track(onset_envelope=onset_env, sr=sample_rate)
    beats = librosa.frames_to_time(beats, sr=sample_rate)
    if len(beats) > 1:
        features.append(float(np.mean(np.diff(beats))))
    else:
        features.append(0.0)
    
    # Rhythm patterns
    stft = librosa.stft(segment, n_fft=2048, hop_length=512)
    magnitude = np.abs(stft)
    NUM_RHYTHM_BANDS = 6
    band_indices = np.linspace(0, magnitude.shape[0], NUM_RHYTHM_BANDS + 1, dtype=int)
    energy_bands = np.zeros((NUM_RHYTHM_BANDS, magnitude.shape[1]))
    for b in range(NUM_RHYTHM_BANDS):
        energy_bands[b] = np.sum(magnitude[band_indices[b]:band_indices[b+1]], axis=0)
    rhythm_features = []
    for b in range(NUM_RHYTHM_BANDS):
        autocorr = np.correlate(energy_bands[b], energy_bands[b], mode='full')
        rhythm_features.extend(autocorr[len(autocorr)//2:])  # Keep non-negative lags
    features.extend(rhythm_features)
    
    # Chroma features (mean)
    chroma = librosa.feature.chroma_stft(y=segment, sr=sample_rate, n_fft=2048, hop_length=512)
    features.extend(np.mean(chroma, axis=1).tolist())
    
    # RMS dynamics
    rms = librosa.feature.rms(y=segment, frame_length=2048, hop_length=512)[0]
    features.append(float(np.mean(rms)))
    features.append(float(np.std(rms)))
    features.append(float((np.max(rms) - np.min(rms)) / (np.max(rms) + 1e-10)))
    
    return features

def load_data(data_path):
    """Modified to load both MFCCs and other features"""
    with open(data_path, "r") as fp:
        data = json.load(fp)
    
    # MFCCs (same as original)
    X_mfcc = np.array(data["mfcc"])
    
    # Other features (new)
    X_other = np.array(data["other_features"])
    
    y = np.array(data["labels"])
    return X_mfcc, X_other, y

def prepare_datasets(test_size, validation_size):
    """Modified version that maintains your augmentation approach"""
    # Load data
    X_mfcc, X_other, y = load_data(JSON_PATH)
    
    # Split data
    (X_mfcc_train, X_mfcc_test, 
     X_other_train, X_other_test, 
     y_train, y_test) = train_test_split(X_mfcc, X_other, y, test_size=test_size)
    
    (X_mfcc_train, X_mfcc_val, 
     X_other_train, X_other_val, 
     y_train, y_val) = train_test_split(X_mfcc_train, X_other_train, y_train, 
                                      test_size=validation_size)

    # === Data Augmentation (same as your original) ===
    # Reverse MFCCs
    X_mfcc_train_reversed = np.flip(X_mfcc_train, axis=1)
    y_train_reversed = y_train.copy()
    
    # Time shifting
    max_shift = int(0.1 * X_mfcc_train.shape[1])
    X_mfcc_train_shifted = []
    X_other_train_shifted = []
    y_train_shifted = []
    
    for i in range(X_mfcc_train.shape[0]):
        shift = np.random.randint(1, max_shift)
        shifted_mfcc = np.roll(X_mfcc_train[i], shift, axis=1)
        X_mfcc_train_shifted.append(shifted_mfcc)
        X_other_train_shifted.append(X_other_train[i])  # Other features don't get shifted
        y_train_shifted.append(y_train[i])
    
    X_mfcc_train_shifted = np.array(X_mfcc_train_shifted)
    X_other_train_shifted = np.array(X_other_train_shifted)
    y_train_shifted = np.array(y_train_shifted)
    
    # Combine original and augmented data
    X_mfcc_train_augmented = np.concatenate(
        (X_mfcc_train, X_mfcc_train_reversed, X_mfcc_train_shifted), axis=0)
    X_other_train_augmented = np.concatenate(
        (X_other_train, X_other_train, X_other_train_shifted), axis=0)
    y_train_augmented = np.concatenate(
        (y_train, y_train_reversed, y_train_shifted), axis=0)
    
    # Shuffle
    indices = np.arange(X_mfcc_train_augmented.shape[0])
    np.random.shuffle(indices)
    X_mfcc_train_augmented = X_mfcc_train_augmented[indices]
    X_other_train_augmented = X_other_train_augmented[indices]
    y_train_augmented = y_train_augmented[indices]
    
    # Normalize other features
    scaler = StandardScaler()
    X_other_train_augmented = scaler.fit_transform(X_other_train_augmented)
    X_other_val = scaler.transform(X_other_val)
    X_other_test = scaler.transform(X_other_test)
    
    # Add channel dimension to MFCCs
    X_mfcc_train_augmented = X_mfcc_train_augmented[..., np.newaxis]
    X_mfcc_val = X_mfcc_val[..., np.newaxis]
    X_mfcc_test = X_mfcc_test[..., np.newaxis]
    
    return (X_mfcc_train_augmented, X_other_train_augmented), \
           (X_mfcc_val, X_other_val), \
           (X_mfcc_test, X_other_test), \
           y_train_augmented, y_val, y_test

# The rest of your functions (plot_history, predict) remain unchanged

if __name__ == "__main__":
    target_genres = ['Rock',
'Punk',
'Post-Rock',
'Indie-Rock',
'Psych-Rock',
'Noise-Rock',
'Singer-Songwriter',
'Folk',
'Psych-Folk',
'Country',
'Blues',
'Metal',
'Post-Punk',
'Industrial',
'Freak-Folk',
'Krautrock']
    
    # Save features (replaces save_mfcc)
    save_features(DATASET_PATH, JSON_PATH, METADATA_PATH, target_genres=target_genres, num_segments=10)
    
    # Prepare datasets
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)
# Out:
# Filtered tracks by target genres: 1600
# Tracks after file check: 1600
# Processing files:   0%|                                                                     | 0/1600 [00:00<?, ?file/s]C:\Users\HASSAN\AppData\Local\Temp\ipykernel_11548\1226271187.py:119: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   features.append(float(tempo))
# Processing files:   3%|█▌                                                          | 43/1600 [00:15<09:23,  2.76file/s]C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# Processing files: 100%|██████████████████████████████████████████████████████████| 1600/1600 [09:09<00:00,  2.91file/s]
# Features saved to data_fma.json

# %%
import json
import os
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization, 
                                    Dropout, Dense, Flatten, Concatenate, Reshape, Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras


def build_hybrid_model(mfcc_shape, other_features_shape, num_classes=16):
    """Hybrid model with original CNN structure for MFCCs and Dense network for other features"""
    # --- CNN Branch (MFCCs) ---
    mfcc_input = Input(shape=mfcc_shape, name='mfcc_input')
    
    # Reshape MFCCs to (time_steps, 13, 1) for Conv2D
    x = Reshape((mfcc_shape[0], mfcc_shape[1], 1))(mfcc_input)
    
    # Original CNN architecture
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = Conv2D(128, (2, 2), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    
    x = Flatten()(x)
    
    # --- Dense Branch (Other Features) ---
    other_input = Input(shape=(other_features_shape,), name='other_input')
    # Layer 1
    y = Dense(64)(other_input)
    y = BatchNormalization()(y)  # BN before activation
    y = Activation('relu')(y)
    y = Dropout(0.2)(y)
    
    # Layer 2 
    y = Dense(128)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Dropout(0.3)(y)
    
    # Layer 3
    y = Dense(128)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Dropout(0.4)(y)
    
    # --- Combine Branches ---
    combined = Concatenate()([x, y])
    
    # Final classification layers
    z = Dense(256, activation='relu')(combined)
    z = Dropout(0.5)(z)
    output = Dense(num_classes, activation='softmax')(z)
    
    return Model(inputs=[mfcc_input, other_input], outputs=output)

def plot_history(history):
    """Plots accuracy/loss for training/validation as a function of the epochs."""
    fig, axs = plt.subplots(2)

    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

def predict(model, X_mfcc, X_other, y):
    """Predict a single sample using the trained model."""
    X_mfcc = X_mfcc[np.newaxis, ...]
    X_other = X_other[np.newaxis, ...]
    prediction = model.predict([X_mfcc, X_other])
    predicted_index = np.argmax(prediction, axis=1)
    print(f"Target: {y}, Predicted label: {predicted_index}")

if __name__ == "__main__":
    # Define target genres
    target_genres = ['Rock',
'Punk',
'Post-Rock',
'Indie-Rock',
'Psych-Rock',
'Noise-Rock',
'Singer-Songwriter',
'Folk',
'Psych-Folk',
'Country',
'Blues',
'Metal',
'Post-Punk',
'Industrial',
'Freak-Folk',
'Krautrock']

    # Prepare datasets (using your modified prepare_datasets function)
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)

    # Build model
    mfcc_shape = X_mfcc_train.shape[1:]  # (time_steps, 13)
    other_shape = X_other_train.shape[1]  # num_other_features
    model = build_hybrid_model(mfcc_shape, other_shape)
    
    # Compile with original hyperparameters
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    model.summary()

    # Train with original settings plus early stopping
    history = model.fit(
        [X_mfcc_train, X_other_train], y_train,
        validation_data=([X_mfcc_val, X_other_val], y_val),
        batch_size=32,
        epochs=300,
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
        ]
    )

    # Plot training history
    plot_history(history)

    # Evaluate on test set
    test_loss, test_acc = model.evaluate([X_mfcc_test, X_other_test], y_test, verbose=2)
    print(f"\nTest Accuracy: {test_acc:.4f}")

    # Make a sample prediction
    sample_idx = 100  # Example index
    predict(model, X_mfcc_test[sample_idx], X_other_test[sample_idx], y_test[sample_idx])
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)       │ (None, 71, 13, 1)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 71, 13, 1)         │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 71, 13, 64)        │             640 │ reshape[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ other_input (InputLayer)      │ (None, 444)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 36, 7, 64)         │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64)                │          28,480 │ other_input[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 36, 7, 64)         │             256 │ max_pooling2d[0][0]        │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 64)                │             256 │ dense[0][0]                │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 36, 7, 64)         │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 64)                │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 36, 7, 128)        │          73,856 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 64)                │               0 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 18, 4, 128)        │               0 │ conv2d_1[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │           8,320 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 18, 4, 128)        │             512 │ max_pooling2d_1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 128)               │             512 │ dense_1[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 18, 4, 128)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_1 (Activation)     │ (None, 128)               │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 18, 4, 128)        │          65,664 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 128)               │               0 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 9, 2, 128)         │               0 │ conv2d_2[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 128)               │          16,512 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 9, 2, 128)         │             512 │ max_pooling2d_2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 128)               │             512 │ dense_2[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 9, 2, 128)         │               0 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_2 (Activation)     │ (None, 128)               │               0 │ batch_normalization_5[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2304)              │               0 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 128)               │               0 │ activation_2[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 2432)              │               0 │ flatten[0][0],             │
# │                               │                           │                 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256)               │         622,848 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 256)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 16)                │           4,112 │ dropout_6[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 822,992 (3.14 MB)
#  Trainable params: 821,712 (3.13 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# Epoch 1/300
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['mfcc_input', 'other_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 31s 24ms/step - accuracy: 0.0880 - loss: 3.2282 - val_accuracy: 0.1441 - val_loss: 2.5853
# Epoch 2/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.1240 - loss: 2.6704 - val_accuracy: 0.1461 - val_loss: 2.5476
# Epoch 3/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.1403 - loss: 2.6123 - val_accuracy: 0.1544 - val_loss: 2.5156
# Epoch 4/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 27s 24ms/step - accuracy: 0.1595 - loss: 2.5585 - val_accuracy: 0.1657 - val_loss: 2.5055
# Epoch 5/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.1740 - loss: 2.5160 - val_accuracy: 0.1833 - val_loss: 2.4368
# Epoch 6/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.1907 - loss: 2.4670 - val_accuracy: 0.1711 - val_loss: 2.4884
# Epoch 7/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2044 - loss: 2.4296 - val_accuracy: 0.1946 - val_loss: 2.4661
# Epoch 8/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2170 - loss: 2.4012 - val_accuracy: 0.2260 - val_loss: 2.4090
# Epoch 9/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2334 - loss: 2.3559 - val_accuracy: 0.2412 - val_loss: 2.3558
# Epoch 10/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2444 - loss: 2.3168 - val_accuracy: 0.2505 - val_loss: 2.3177
# Epoch 11/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2553 - loss: 2.2843 - val_accuracy: 0.2549 - val_loss: 2.3118
# Epoch 12/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2691 - loss: 2.2404 - val_accuracy: 0.2583 - val_loss: 2.2639
# Epoch 13/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2792 - loss: 2.2067 - val_accuracy: 0.2730 - val_loss: 2.2778
# Epoch 14/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2942 - loss: 2.1679 - val_accuracy: 0.2853 - val_loss: 2.2022
# Epoch 15/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2979 - loss: 2.1532 - val_accuracy: 0.3088 - val_loss: 2.1191
# Epoch 16/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2999 - loss: 2.1255 - val_accuracy: 0.2995 - val_loss: 2.1682
# Epoch 17/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.3194 - loss: 2.0919 - val_accuracy: 0.3010 - val_loss: 2.1891
# Epoch 18/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.3233 - loss: 2.0622 - val_accuracy: 0.3113 - val_loss: 2.1107
# Epoch 19/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.3337 - loss: 2.0378 - val_accuracy: 0.3358 - val_loss: 2.0589
# Epoch 20/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.3393 - loss: 2.0129 - val_accuracy: 0.3240 - val_loss: 2.0507
# Epoch 21/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.

# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#              Rock      0.734     0.730     0.732       159
#              Punk      0.776     0.844     0.808       160
#         Post-Rock      0.801     0.790     0.796       138
#        Indie-Rock      0.742     0.702     0.722       168
#        Psych-Rock      0.812     0.738     0.773       141
#        Noise-Rock      0.879     0.804     0.840       153
# Singer-Songwriter      0.667     0.642     0.654       159
#              Folk      0.750     0.838     0.791       154
#        Psych-Folk      0.758     0.651     0.700       149
#           Country      0.629     0.769     0.692       143
#             Blues      0.819     0.781     0.800       151
#             Metal      0.885     0.811     0.847       143
#         Post-Punk      0.583     0.695     0.634       141
#        Industrial      0.824     0.824     0.824       142
#        Freak-Folk      0.758     0.758     0.758       149
#         Krautrock      0.832     0.793     0.812       150
#
#          accuracy                          0.760      2400
#         macro avg      0.766     0.761     0.761      2400
#      weighted avg      0.765     0.760     0.761      2400
#
#
# Class Distribution in Test Set:
# Rock                : 72.96% (159 samples)
# Punk                : 84.38% (160 samples)
# Post-Rock           : 78.99% (138 samples)
# Indie-Rock          : 70.24% (168 samples)
# Psych-Rock          : 73.76% (141 samples)
# Noise-Rock          : 80.39% (153 samples)
# Singer-Songwriter   : 64.15% (159 samples)
# Folk                : 83.77% (154 samples)
# Psych-Folk          : 65.10% (149 samples)
# Country             : 76.92% (143 samples)
# Blues               : 78.15% (151 samples)
# Metal               : 81.12% (143 samples)
# Post-Punk           : 69.50% (141 samples)
# Industrial          : 82.39% (142 samples)
# Freak-Folk          : 75.84% (149 samples)
# Krautrock           : 79.33% (150 samples)

# %%
import json
import os
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization, 
                                    Dropout, Dense, Flatten, Concatenate, Reshape,
                                    Bidirectional, GRU, Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras

def build_hybrid_parallel_model(mfcc_shape, other_features_shape, num_classes=16):
    """Hybrid model with CNN+BGRU for MFCCs and Dense network for other features"""
    
    # --- MFCC Input Branch (CNN + BGRU) ---
    mfcc_input = Input(shape=mfcc_shape, name='mfcc_input')
    
    # Reshape MFCCs to (time_steps, 13, 1) for Conv2D
    x = Reshape((mfcc_shape[0], mfcc_shape[1], 1))(mfcc_input)
    
    # --- CNN Branch ---
    cnn_branch = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    cnn_branch = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(cnn_branch)
    cnn_branch = BatchNormalization()(cnn_branch)
    cnn_branch = Dropout(0.2)(cnn_branch)
    
    cnn_branch = Conv2D(128, (3, 3), activation='relu', padding='same')(cnn_branch)
    cnn_branch = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(cnn_branch)
    cnn_branch = BatchNormalization()(cnn_branch)
    cnn_branch = Dropout(0.3)(cnn_branch)
    
    cnn_branch = Conv2D(128, (2, 2), activation='relu', padding='same')(cnn_branch)
    cnn_branch = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(cnn_branch)
    cnn_branch = BatchNormalization()(cnn_branch)
    cnn_branch = Dropout(0.4)(cnn_branch)
    
    cnn_branch = Flatten()(cnn_branch)
    
    # --- BGRU Branch ---
    time_steps = mfcc_shape[0]
    features = mfcc_shape[1]  # 13 MFCC coefficients
    reshaped_mfcc = Reshape((time_steps, features))(mfcc_input)
    
    bgru_branch = Bidirectional(GRU(128, return_sequences=False))(reshaped_mfcc)
    bgru_branch = BatchNormalization()(bgru_branch)
    bgru_branch = Dropout(0.4)(bgru_branch)
    
    
    
    
    # --- Other Features Branch ---
    other_input = Input(shape=(other_features_shape,), name='other_input')
    other_branch = Dense(128)(other_input)
    other_branch = BatchNormalization()(other_branch)  # BN before activation
    other_branch = Activation('relu')(other_branch)
    other_branch = Dropout(0.4)(other_branch)
    
    # Layer 2 
    

    
    # --- Combine All Branches ---
    combined = Concatenate()([cnn_branch, bgru_branch, other_branch])
    
    # Final classification layers
    dense = Dense(256, activation='relu')(combined)
    dense = Dropout(0.5)(dense)
    output = Dense(num_classes, activation='softmax')(dense)
    
    return Model(inputs=[mfcc_input, other_input], outputs=output)

def plot_history(history):
    """Plots accuracy/loss for training/validation as a function of the epochs."""
    fig, axs = plt.subplots(2)

    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

def predict(model, X_mfcc, X_other, y):
    """Predict a single sample using the trained model."""
    X_mfcc = X_mfcc[np.newaxis, ...]
    X_other = X_other[np.newaxis, ...]
    prediction = model.predict([X_mfcc, X_other])
    predicted_index = np.argmax(prediction, axis=1)
    print(f"Target: {y}, Predicted label: {predicted_index}")

if __name__ == "__main__":
    # Define target genres
    target_genres = ['Rock',
'Punk',
'Post-Rock',
'Indie-Rock',
'Psych-Rock',
'Noise-Rock',
'Singer-Songwriter',
'Folk',
'Psych-Folk',
'Country',
'Blues',
'Metal',
'Post-Punk',
'Industrial',
'Freak-Folk',
'Krautrock']

    # Prepare datasets (using your modified prepare_datasets function)
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)

    # Build model
    mfcc_shape = X_mfcc_train.shape[1:]  # (time_steps, 13)
    other_shape = X_other_train.shape[1]  # num_other_features
    model = build_hybrid_parallel_model(mfcc_shape, other_shape)
    
    # Compile with original hyperparameters
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    model.summary()

    # Train with original settings plus early stopping
    history = model.fit(
        [X_mfcc_train, X_other_train], y_train,
        validation_data=([X_mfcc_val, X_other_val], y_val),
        batch_size=32,
        epochs=300,
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
        ]
    )

    # Plot training history
    plot_history(history)

    # Evaluate on test set
    test_loss, test_acc = model.evaluate([X_mfcc_test, X_other_test], y_test, verbose=2)
    print(f"\nTest Accuracy: {test_acc:.4f}")

    # Make a sample prediction
    sample_idx = 100  # Example index
    predict(model, X_mfcc_test[sample_idx], X_other_test[sample_idx], y_test[sample_idx])
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)       │ (None, 71, 13, 1)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_1 (Reshape)           │ (None, 71, 13, 1)         │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 71, 13, 64)        │             640 │ reshape_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 36, 7, 64)         │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 36, 7, 64)         │             256 │ max_pooling2d_3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_7 (Dropout)           │ (None, 36, 7, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 36, 7, 128)        │          73,856 │ dropout_7[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 18, 4, 128)        │               0 │ conv2d_4[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 18, 4, 128)        │             512 │ max_pooling2d_4[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_8 (Dropout)           │ (None, 18, 4, 128)        │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 18, 4, 128)        │          65,664 │ dropout_8[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ other_input (InputLayer)      │ (None, 444)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 9, 2, 128)         │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_2 (Reshape)           │ (None, 71, 13)            │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 128)               │          56,960 │ other_input[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 9, 2, 128)         │             512 │ max_pooling2d
300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.7931 - loss: 0.6133 - val_accuracy: 0.7672 - val_loss: 0.7799
# Epoch 249/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 79s 72ms/step - accuracy: 0.7942 - loss: 0.6054 - val_accuracy: 0.7730 - val_loss: 0.7835
# Epoch 250/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.7995 - loss: 0.5854 - val_accuracy: 0.7784 - val_loss: 0.7591
# Epoch 251/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.8000 - loss: 0.5945 - val_accuracy: 0.7706 - val_loss: 0.7672
# Epoch 252/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.7945 - loss: 0.6039 - val_accuracy: 0.7691 - val_loss: 0.7848
# Epoch 253/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.7971 - loss: 0.6002 - val_accuracy: 0.7701 - val_loss: 0.7924
# Epoch 254/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 80s 73ms/step - accuracy: 0.7960 - loss: 0.5906 - val_accuracy: 0.7755 - val_loss: 0.7794
# Epoch 255/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.8009 - loss: 0.5971 - val_accuracy: 0.7789 - val_loss: 0.7709
# Epoch 256/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.8028 - loss: 0.5874 - val_accuracy: 0.7804 - val_loss: 0.7818
# Epoch 257/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.8026 - loss: 0.5946 - val_accuracy: 0.7755 - val_loss: 0.7825
# Epoch 258/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.8023 - loss: 0.5877 - val_accuracy: 0.7775 - val_loss: 0.7798
# Epoch 259/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 80s 73ms/step - accuracy: 0.8047 - loss: 0.5879 - val_accuracy: 0.7750 - val_loss: 0.7717
# 75/75 - 1s - 19ms/step - accuracy: 0.7638 - loss: 0.8411
#
# Test Accuracy: 0.7638
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# Target: 11, Predicted label: [11]

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# Load genre labels
with open(JSON_PATH, "r") as fp:
    genre_labels = json.load(fp)["mapping"]

# ================================================
# Single Sample Prediction
# ================================================
sample_idx = 100
X_mfcc_to_predict = X_mfcc_test[sample_idx]
X_other_to_predict = X_other_test[sample_idx]
y_to_predict = y_test[sample_idx]

# Predict and show results
predicted = model.predict([X_mfcc_to_predict[np.newaxis, ...], 
                         X_other_to_predict[np.newaxis, ...]])
print(f"\nTrue Genre: {genre_labels[y_to_predict]}")
print(f"Predicted Genre: {genre_labels[np.argmax(predicted)]}")
print(f"Confidence: {np.max(predicted) * 100:.2f}%")

# ================================================
# Full Test Set Evaluation
# ================================================
# Generate predictions
y_pred = model.predict([X_mfcc_test, X_other_test])
y_pred_labels = np.argmax(y_pred, axis=1)

# Compute normalized confusion matrix (row-wise)
conf_matrix = confusion_matrix(y_test, y_pred_labels)
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Create plot
plt.figure(figsize=(14, 12))
disp = ConfusionMatrixDisplay(
    confusion_matrix=conf_matrix_norm,
    display_labels=[genre_labels[i] for i in range(len(genre_labels))]
)
disp.plot(
    cmap='Blues',
    ax=plt.gca(),
    xticks_rotation=45,
    values_format='.2f',  # Show 2 decimal places
    colorbar=False
)

# Add custom annotations
for i in range(len(genre_labels)):
    for j in range(len(genre_labels)):
        value = conf_matrix_norm[i, j]
        plt.text(j, i, f"{value:.2f}",
                ha="center", va="center",
                color="white" if value > 0.5 else "black",
                fontsize=10)

# Formatting
plt.title(f"Confusion Matrix\nTest Accuracy: {accuracy_score(y_test, y_pred_labels):.2%}", 
          pad=20, fontsize=14)
plt.xlabel("Predicted Genre", fontsize=12, labelpad=15)
plt.ylabel("True Genre", fontsize=12, labelpad=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()

# Print detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels, 
                           target_names=genre_labels, digits=3))

# Show class distribution
print("\nClass Distribution in Test Set:")
for i, genre in enumerate(genre_labels):
    count = sum(y_test == i)
    if count > 0:
        acc = accuracy_score(y_test[y_test == i], y_pred_labels[y_test == i])
        print(f"{genre:<20}: {acc:.2%} ({count} samples)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# True Genre: Metal
# Predicted Genre: Metal
# Confidence: 98.74%
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#              Rock      0.777     0.614     0.686       153
#              Punk      0.768     0.838     0.801       142
#         Post-Rock      0.776     0.786     0.781       154
#        Indie-Rock      0.752     0.746     0.749       138
#        Psych-Rock      0.786     0.733     0.759       165
#        Noise-Rock      0.806     0.822     0.814       152
# Singer-Songwriter      0.676     0.669     0.673       172
#              Folk      0.667     0.752     0.707       141
#        Psych-Folk      0.759     0.759     0.759       145
#           Country      0.652     0.777     0.709       157
#             Blues      0.870     0.774     0.819       155
#             Metal      0.857     0.745     0.797       161
#         Post-Punk      0.730     0.753     0.741       154
#        Industrial      0.854     0.854     0.854       137
#        Freak-Folk      0.779     0.796     0.787       137
#         Krautrock      0.782     0.839     0.810       137
#
#          accuracy                          0.764      2400
#         macro avg      0.768     0.766     0.765      2400
#      weighted avg      0.768     0.764     0.764      2400
#
#
# Class Distribution in Test Set:
# Rock                : 61.44% (153 samples)
# Punk                : 83.80% (142 samples)
# Post-Rock           : 78.57% (154 samples)
# Indie-Rock          : 74.64% (138 samples)
# Psych-Rock          : 73.33% (165 samples)
# Noise-Rock          : 82.24% (152 samples)
# Singer-Songwriter   : 66.86% (172 samples)
# Folk                : 75.18% (141 samples)
# Psych-Folk          : 75.86% (145 samples)
# Country             : 77.71% (157 samples)
# Blues               : 77.42% (155 samples)
# Metal               : 74.53% (161 samples)
# Post-Punk           : 75.32% (154 samples)
# Industrial          : 85.40% (137 samples)
# Freak-Folk          : 79.56% (137 samples)
# Krautrock           : 83.94% (137 samples)

# %%
import json
import os
import math
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, GlobalAveragePooling1D, Activation, Concatenate
from tensorflow.keras.layers import PReLU, Layer, BatchNormalization
from tqdm import tqdm
import tensorflow as tf

# Configurations - Added USE_BATCH_NORM flag
class Config:
    MCLNN_LAYER_COUNT = 3
    DENSE_LAYER_COUNT = 2
    TOTAL_LAYER_COUNT = MCLNN_LAYER_COUNT + DENSE_LAYER_COUNT
    HIDDEN_NODES_LIST = [220, 200, 180]
    OTHER_FEATURES_NODES = [128, 64]
    DENSE_NODES = [50, 16]
    MASK_BANDWIDTH = [40, 10, 5]
    MASK_OVERLAP = [-10, 3, 1]
    LAYERS_ORDER_LIST = [4, 4, 4]
    LAYER_IS_MASKED = [True, True, True]
    DROPOUT = [0.01, 0.4, 0.2, 0.1, 0.2]
    OTHER_FEATURES_DROPOUT = [0.15, 0.15]
    WEIGHT_INITIALIZATION = ['he_normal', 'he_normal', 'he_normal', 'glorot_uniform', 'glorot_uniform']
    LEARNING_RATE = 0.0001
    USE_BATCH_NORM = True  # New flag to control batch normalization

# MaskedConditional Layer (unchanged)
class MaskedConditional(Layer):
    def __init__(self, output_dim, init='glorot_uniform', order=5, bandwidth=1, overlap=0, layer_is_masked=True, **kwargs):
        super(MaskedConditional, self).__init__(**kwargs)
        self.output_dim = output_dim
        self.init = keras.initializers.get(init)
        self.order = order
        self.bandwidth = bandwidth
        self.overlap = overlap
        self.layer_is_masked = layer_is_masked

    def build(self, input_shape):
        input_dim = input_shape[-1]
        kernel_size = self.order * 2 + 1
        self.kernel_size = kernel_size

        self.W = self.add_weight(
            shape=(kernel_size, input_dim, self.output_dim),
            initializer=self.init,
            trainable=True,
            name='weights'
        )
        self.b = self.add_weight(
            shape=(self.output_dim,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

        self.weightmask = self.construct_mask(
            input_dim, self.output_dim, self.bandwidth, self.overlap, self.layer_is_masked
        )
        self.weightmask = tf.expand_dims(self.weightmask, axis=0)
        self.weightmask = tf.tile(self.weightmask, [kernel_size, 1, 1])
        self.W.assign(self.W * self.weightmask)

        super(MaskedConditional, self).build(input_shape)

    def construct_mask(self, feature_count, hidden_count, bandwidth, overlap, layer_is_masked):
        bw = bandwidth
        ov = overlap
        l = feature_count
        e = hidden_count

        a = np.arange(1, bw + 1)
        g = np.arange(1, int(np.ceil((l * e) / (l + bw - ov))) + 1)

        if not layer_is_masked:
            binary_mask = np.ones([l, e])
        else:
            mask = np.zeros([l, e])
            flat_matrix = mask.flatten('F')

            for i in range(len(a)):
                for j in range(len(g)):
                    lx = a[i] + (g[j] - 1) * (l + bw - ov)
                    if lx <= l * e:
                        flat_matrix[lx - 1] = 1

            binary_mask = np.transpose(flat_matrix.reshape(e, l))

        return binary_mask.astype(np.float32)

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        sequence_length = tf.shape(inputs)[1]
        feature_count = tf.shape(inputs)[2]

        padding = self.order
        padded_inputs = tf.pad(inputs, [[0, 0], [padding, padding], [0, 0]], mode='CONSTANT')

        outputs = tf.nn.conv1d(padded_inputs, self.W, stride=1, padding='VALID')
        outputs = outputs + self.b
        return outputs

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1], self.output_dim)

# Updated build_parallel_model with BatchNormalization
def build_parallel_model(mfcc_shape, other_features_dim, num_classes=16):
    # MFCC input branch
    mfcc_input = Input(shape=(mfcc_shape[0], mfcc_shape[1]), name='mfcc_input')
    x_mfcc = mfcc_input
    
    # Other features input branch
    other_input = Input(shape=(other_features_dim,), name='other_features_input')
    x_other = other_input
    
    # Process MFCC features through MCLNN layers with BatchNorm
    for layer_index in range(Config.MCLNN_LAYER_COUNT):
        x_mfcc = Dropout(Config.DROPOUT[layer_index])(x_mfcc)
        x_mfcc = MaskedConditional(
            init=Config.WEIGHT_INITIALIZATION[layer_index],
            output_dim=Config.HIDDEN_NODES_LIST[layer_index],
            order=Config.LAYERS_ORDER_LIST[layer_index],
            bandwidth=Config.MASK_BANDWIDTH[layer_index],
            overlap=Config.MASK_OVERLAP[layer_index],
            layer_is_masked=Config.LAYER_IS_MASKED[layer_index]
        )(x_mfcc)
        if Config.USE_BATCH_NORM:
            x_mfcc = BatchNormalization()(x_mfcc)
        x_mfcc = PReLU(shared_axes=[1])(x_mfcc)
    
    # Process other features through dense layers with BatchNorm
    for i, nodes in enumerate(Config.OTHER_FEATURES_NODES):
        x_other = Dropout(Config.OTHER_FEATURES_DROPOUT[i])(x_other)
        x_other = Dense(nodes, activation='relu')(x_other)
        if Config.USE_BATCH_NORM:
            x_other = BatchNormalization()(x_other)
    
    # Global pooling for MFCC features
    mfcc_features = GlobalAveragePooling1D()(x_mfcc)
    
    # Concatenate both feature streams
    combined = Concatenate()([mfcc_features, x_other])
    
    # Add final dense layers with BatchNorm
    for i in range(Config.DENSE_LAYER_COUNT):
        combined = Dropout(Config.DROPOUT[i + Config.MCLNN_LAYER_COUNT])(combined)
        combined = Dense(
            units=Config.DENSE_NODES[i],
            kernel_initializer=Config.WEIGHT_INITIALIZATION[i + Config.MCLNN_LAYER_COUNT]
        )(combined)
        if Config.USE_BATCH_NORM:
            combined = BatchNormalization()(combined)
        if i < Config.DENSE_LAYER_COUNT - 1:
            combined = PReLU()(combined)
        else:
            combined = Activation('softmax')(combined)
    
    model = Model(inputs=[mfcc_input, other_input], outputs=combined)
    optimiser = keras.optimizers.Adam(learning_rate=Config.LEARNING_RATE)
    model.compile(optimizer=optimiser, 
                 loss='sparse_categorical_crossentropy', 
                 metrics=['accuracy'])
    return model

# Main execution remains the same
if __name__ == "__main__":
    # Prepare datasets (now returns both MFCC and other features)
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)

    # Squeeze the last dimension if it's 1 (remove unnecessary channels dimension)
    X_mfcc_train = X_mfcc_train.squeeze(-1)
    X_mfcc_val = X_mfcc_val.squeeze(-1)
    X_mfcc_test = X_mfcc_test.squeeze(-1)

    print(f"MFCC train shape: {X_mfcc_train.shape}, Other features train shape: {X_other_train.shape}")
    print(f"MFCC val shape: {X_mfcc_val.shape}, Other features val shape: {X_other_val.shape}")

    # Build and compile the model
    mfcc_shape = (X_mfcc_train.shape[1], X_mfcc_train.shape[2])
    other_features_dim = X_other_train.shape[1]
    model = build_parallel_model(mfcc_shape, other_features_dim)
    model.summary()

    # Add callbacks
    callbacks = [
        keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=10)
    ]

    # Train the model
    history = model.fit(
        [X_mfcc_train, X_other_train], y_train,
        validation_data=([X_mfcc_val, X_other_val], y_val),
        batch_size=32,
        epochs=300,
        callbacks=callbacks
    )

    # Evaluate the model on the test set
    test_loss, test_acc = model.evaluate([X_mfcc_test, X_other_test], y_test, verbose=2)
    print(f'\nTest accuracy: {test_acc}')
    plot_history(history)
    
    # Predict a sample from the test set
    X_mfcc_to_predict = X_mfcc_test[100][np.newaxis, ...]
    X_other_to_predict = X_other_test[100][np.newaxis, ...]
    y_to_predict = y_test[100]
    predict(model, [X_mfcc_to_predict, X_other_to_predict], y_to_predict)
# Out:
# MFCC train shape: (34680, 71, 13), Other features train shape: (34680, 444)
# MFCC val shape: (2040, 71, 13), Other features val shape: (2040, 444)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)       │ (None, 71, 13)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_13 (Dropout)          │ (None, 71, 13)            │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ masked_conditional            │ (None, 71, 220)           │          25,960 │ dropout_13[0][0]           │
# │ (MaskedConditional)           │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 71, 220)           │             880 │ masked_conditional[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu (PReLU)               │ (None, 71, 220)           │             220 │ batch_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_14 (Dropout)          │ (None, 71, 220)           │               0 │ p_re_lu[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ masked_conditional_1          │ (None, 71, 200)           │         396,200 │ dropout_14[0][0]           │
# │ (MaskedConditional)           │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 71, 200)           │             800 │ masked_conditional_1[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ other_features_input          │ (None, 444)               │               0 │ -                          │
# │ (InputLayer)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu_1 (PReLU)             │ (None, 71, 200)           │             200 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_16 (Dropout)          │ (None, 444)               │               0 │ other_features_input[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_15 (Dropout)          │ (None, 71, 200)           │               0 │ p_re_lu_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 128)               │          56,960 │ dropout_16[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ masked_conditional_2          │ (None, 71, 180)           │         324,180 │ dropout_15[0][0]           │
# │ (MaskedConditional)           │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 128)               │             512 │ dense_8[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 71, 180)           │             720 │ masked_conditional_2[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_17 (Dropout)          │ (None, 128)               │               0 │ batch_normalization_14[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu_2 (PReLU)             │ (None, 71, 180)           │             180 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 64)                │           8,256 │ dropout_17[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 180)               │               0 │ p_re_lu_2[0][0]            │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_15        │ (None, 64)                │             256 │ dense_9[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 244)               │               0 │ global_average_pooling1d[… │
# │                               │                           │                 │ batch_normalization_15[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_18 (Dropout)          │ (None, 244)               │               0 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 50)                │          12,250 │ dropout_18[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_16        │ (None, 50)                │             200 │ dense_10[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu_3 (PReLU)             │ (None, 50)                │              50 │ batch_normalization_16[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_19 (Dropout)          │ (None, 50)                │               0 │ p_re_lu_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 16)                │             816 │ dropout_19[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_17        │ (None, 16)                │              64 │ dense_11[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_4 (Activation)     │ (None, 16)                │               0 │ batch_normalization_17[0]… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 828,704 (3.16 MB)
#  Trainable params: 826,988 (3.15 MB)
#  Non-trainable params: 1,716 (6.70 KB)
# Epoch 1/300
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['mfcc_input', 'other_features_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 63s 53ms/step - accuracy: 0.1187 - loss: 2.8217 - val_accuracy: 0.2186 - val_loss: 2.4364 - learning_rate: 1.0000e-04
# Epoch 2/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 55s 50ms/step - accuracy: 0.1884 - loss: 2.5079 - val_accuracy: 0.2451 - val_loss: 2.3144 - learning_rate: 1.0000e-04
# Epoch 3/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.2206 - loss: 2.4134 - val_accuracy: 0.2853 - val_loss: 2.2270 - learning_rate: 1.0000e-04
# Epoch 4/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.2412 - loss: 2.3403 - val_accuracy: 0.2951 - val_loss: 2.1736 - learning_rate: 1.0000e-04
# Epoch 5/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.2607 - loss: 2.2868 - val_accuracy: 0.3402 - val_loss: 2.0935 - learning_rate: 1.0000e-04
# Epoch 6/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.2794 - loss: 2.2268 - val_accuracy: 0.3525 - val_loss: 2.0385 - learning_rate: 1.0000e-04
# Epoch 7/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.2907 - loss: 2.1989 - val_accuracy: 0.3471 - val_loss: 2.0361 - learning_rate: 1.0000e-04
# Epoch 8/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.3099 - loss: 2.1603 - val_accuracy: 0.3917 - val_loss: 1.9273 - learning_rate: 1.0000e-04
# Epoch 9/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.3222 - loss: 2.1156 - val_accuracy: 0.4147 - val_loss: 1.8839 - learning_rate: 1.0000e-04
# Epoch 10/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.3293 - loss: 2.0918 - val_accuracy: 0.4328 - val_loss: 1.8514 - learning_rate: 1.0000e-04
# Epoch 11/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.3477 - loss: 2.0447 - val_accuracy: 0.4471 - val_loss: 1.8050 - learning_rate: 1.0000e-04
# Epoch 12/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 48ms/step - accuracy: 0.3605 - loss: 2.0115 - val_accuracy: 0.4461 - val_loss: 1.7836 - learning_rate: 1.0000e-04
# Epoch 13/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 52s 48ms/step - accuracy: 0.3709 - loss: 1.9771 - val_accuracy: 0.4750 - val_loss: 1.7251 - learning_rate: 1.0000e-04
# Epoch 14/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.3722 - loss: 1.9661 - val_accuracy: 0.4926 - val_loss: 1.6836 - learning_rate: 1.0000e-04
# Epoch 15/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.3886 - loss: 1.9290 - val_accuracy: 0.4887 - val_loss: 1.6811 - learning_rate: 1.0000e-04
# Epoch 16/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.3930 - loss: 1.9071 - val_accuracy: 0.5113 - val_loss: 1.6322 - learning_rate: 1.0000e-04
# Epoch 17/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4090 - loss: 1.8675 - val_accuracy: 0.4971 - val_loss: 1.6196 - learning_rate: 1.0000e-04
# Epoch 18/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4138 - loss: 1.8500 - val_accuracy: 0.5309 - val_loss: 1.5841 - learning_rate: 1.0000e-04
# Epoch 19/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4195 - loss: 1.8354 - val_accuracy: 0.5319 - val_loss: 1.5856 - learning_rate: 1.0000e-04
# Epoch 20/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4255 - loss: 1.8062 - val_accuracy: 0.5475 - val_loss: 1.5376 - learning_rate: 1.0000e-04
# Epoch 21/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 55s 50ms/step - accuracy: 0.4337 - loss: 1.7827 - val_accuracy: 0.5328 - val_loss: 1.5108 - learning_rate: 1.0000e-04
# Epoch 22/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 55s 51ms/step - accuracy: 0.4310 - loss: 1.7774 - val_accuracy: 0.5564 - val_loss: 1.4873 - learning_rate: 1.0000e-04
# Epoch 23/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4510 - loss: 1.7316 - val_accuracy: 0.5730 - val_loss: 1.4338 - learning_rate: 1.0000e-04
# Epoch 24/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 52s 48ms/step - accuracy: 0.4492 - loss: 1.7261 - val_accuracy: 0.5721 - val_loss: 1.4453 - learning_rate: 1.0000e-04
# Epoch 25/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.4573 - loss: 1.7093 - val_accuracy: 0.5912 - val_loss: 1.3816 - learning_rate: 1.0000e-04
# Epoch 26/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4637 - loss: 1.6920 - val_accuracy: 0.5917 - val_loss: 1.3788 - learning_rate: 1.0000e-04
# Epoch 27/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.4732 - loss: 1.6639 - val_accuracy: 0.6098 - val_loss: 1.3451 - learning_rate: 1.0000e-04
# Epoch 28/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 55s 51ms/step - accuracy: 0.4709 - loss: 1.6608 - val_accuracy: 0.6132 - val_loss: 1.3281 - learning_rate: 1.0000e-04
# Epoch 29/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 52ms/step - accuracy: 0.4801 - loss: 1.6455 - val_accuracy: 0.6137 - val_loss: 1.3110 - learning_rate: 1.0000e-04
# Epoch 30/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.4818 - loss: 1.6360 - val_accuracy: 0.5990 - val_loss: 1.3293 - learning_rate: 1.0000e-04
# Epoch 31/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 52ms/step - accuracy: 0.4960 - loss: 1.6003 - val_accuracy: 0.6059 - val_loss: 1.3130 - learning_rate: 1.0000e-04
# Epoch 32/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 52ms/step - accuracy: 0.4948 - loss: 1.5823 - val_accuracy: 0.6176 - val_loss: 1.2783 - learning_rate: 1.0000e-04
# Epoch 33/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 52ms/step - accuracy: 0.4889 - loss: 1.5931 - val_accuracy: 0.6309 - val_loss: 1.2540 - learning_rate: 1.0000e-04
# Epoch 34/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 52ms/step - accuracy: 0.5019 - loss: 1.5598 - val_accuracy: 0.6412 - val_loss: 1.2429 - learning_rate: 1.0000e-04
# Epoch 35/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.5055 - loss: 1.5495 - val_accuracy: 0.6250 - val_loss: 1.2514 - learning_rate: 1.0000e-04
# Epoch 36/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.5113 - loss: 1.5363 - val_accuracy: 0.6495 - val_loss: 1.2079 - learning_rate: 1.0000e-04
# Epoch 37/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 52ms/step - accuracy: 0.5186 - loss: 1.5179 - val_accuracy: 0.6554 - val_loss: 1.1791 - learning_rate: 1.0000e-04
# Epoch 38/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.5154 - loss: 1.5212 - val_accuracy: 0.6696 - val_loss: 1.1639 - learning_rate: 1.0000e-04
# Epoch 39/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.5159 - loss: 1.5090 - val_accuracy: 0.6672 - val_loss: 1.1324 - learning_rate: 1.0000e-04
# Epoch 40/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.5281 - loss: 1.4831 - val_accuracy: 0.6740 - val_loss: 1.1419 - learning_rate: 1.0000e-04
# Epoch 41/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 53ms/step - accuracy: 0.5292 - loss: 1.4703 - val_accuracy: 0.6863 - val_loss: 1.1056 - learning_rate: 1.0000e-04
# Epoch 42/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 53ms/step - accuracy: 0.5389 - loss: 1.4575 - val_accuracy: 0.6809 - val_loss: 1.1229 - learning_rate: 1.0000e-04
# Epoch 43/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 53ms/step - accuracy: 0.5362 - loss: 1.4533 - val_accuracy: 0.6721 - val_loss: 1.1136 - learning_rate: 1.0000e-04
# Epoch 44/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 53ms/step - accuracy: 0.5420 - loss: 1.4340 - val_accuracy: 0.6833 - val_loss: 1.0871 - learning_rate: 1.0000e-04
# Epoch 45/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 54ms/step - accuracy: 0.5436 - loss: 1.4309 - val_accuracy: 0.6848 - val_loss: 1.0602 - learning_rate: 1.0000e-04
# Epoch 46/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 53ms/step - accuracy: 0.5485 - loss: 1.4192 - val_accuracy: 0.6868 - val_loss: 1.0494 - learning_rate: 1.0000e-04
# Epoch 47/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 59s 54ms/step - accuracy: 0.5495 - loss: 1.4031 - val_accuracy: 0.7103 - val_loss: 1.0294 - learning_rate: 1.0000e-04
# Epoch 48/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 53ms/step - accuracy: 0.5531 - loss: 1.3960 - val_accuracy: 0.6951 - val_loss: 1.0517 - learning_rate: 1.0000e-04
# Epoch 49/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 52ms/step - accuracy: 0.5482 - loss: 1.4104 - val_accuracy: 0.6985 - val_loss: 1.0434 - learning_rate: 1.0000e-04
# Epoch 50/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 51ms/step - accuracy: 0.5561 - loss: 1.3872 - val_accuracy: 0.7147 - val_loss: 1.0091 - learning_rate: 1.0000e-04
# Epoch 51/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 56s 51ms/step - accuracy: 0.5614 - loss: 1.3700 - val_accuracy: 0.7044 - val_loss: 1.0191 - learning_rate: 1.0000e-04
# Epoch 52/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 49ms/step - accuracy: 0.5669 - loss: 1.3507 - val_accuracy: 0.7132 - val_loss: 0.9968 - learning_rate: 1.0000e-04
# Epoch 53/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5678 - loss: 1.3532 - val_accuracy: 0.7181 - val_loss: 0.9864 - learning_rate: 1.0000e-04
# Epoch 54/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5647 - loss: 1.3598 - val_accuracy: 0.7221 - val_loss: 0.9677 - learning_rate: 1.0000e-04
# Epoch 55/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5726 - loss: 1.3405 - val_accuracy: 0.7123 - val_loss: 0.9744 - learning_rate: 1.0000e-04
# Epoch 56/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5724 - loss: 1.3348 - val_accuracy: 0.7127 - val_loss: 0.9715 - learning_rate: 1.0000e-04
# Epoch 57/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5840 - loss: 1.3155 - val_accuracy: 0.7279 - val_loss: 0.9425 - learning_rate: 1.0000e-04
# Epoch 58/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5708 - loss: 1.3319 - val_accuracy: 0.7142 - val_loss: 0.9564 - learning_rate: 1.0000e-04
# Epoch 59/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5712 - loss: 1.3265 - val_accuracy: 0.7098 - val_loss: 0.9476 - learning_rate: 1.0000e-04
# Epoch 60/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5875 - loss: 1.2906 - val_accuracy: 0.7221 - val_loss: 0.9536 - learning_rate: 1.0000e-04
# Epoch 61/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5772 - loss: 1.3049 - val_accuracy: 0.7152 - val_loss: 0.9592 - learning_rate: 1.0000e-04
# Epoch 62/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5824 - loss: 1.2926 - val_accuracy: 0.7250 - val_loss: 0.9451 - learning_rate: 1.0000e-04
# Epoch 63/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5789 - loss: 1.3020 - val_accuracy: 0.7181 - val_loss: 0.9256 - learning_rate: 1.0000e-04
# Epoch 64/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5902 - loss: 1.2848 - val_accuracy: 0.7221 - val_loss: 0.9405 - learning_rate: 1.0000e-04
# Epoch 65/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5936 - loss: 1.2693 - val_accuracy: 0.7373 - val_loss: 0.8934 - learning_rate: 1.0000e-04
# Epoch 66/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5972 - loss: 1.2548 - val_accuracy: 0.7422 - val_loss: 0.8907 - learning_rate: 1.0000e-04
# Epoch 67/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5949 - loss: 1.2649 - val_accuracy: 0.7319 - val_loss: 0.8992 - learning_rate: 1.0000e-04
# Epoch 68/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5939 - loss: 1.2497 - val_accuracy: 0.7083 - val_loss: 0.9441 - learning_rate: 1.0000e-04
# Epoch 69/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.5989 - loss: 1.2489 - val_accuracy: 0.7422 - val_loss: 0.8791 - learning_rate: 1.0000e-04
# Epoch 70/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6052 - loss: 1.2403 - val_accuracy: 0.7392 - val_loss: 0.8731 - learning_rate: 1.0000e-04
# Epoch 71/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6002 - loss: 1.2397 - val_accuracy: 0.7368 - val_loss: 0.8808 - learning_rate: 1.0000e-04
# Epoch 72/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6068 - loss: 1.2253 - val_accuracy: 0.7387 - val_loss: 0.8747 - learning_rate: 1.0000e-04
# Epoch 73/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6074 - loss: 1.2265 - val_accuracy: 0.7475 - val_loss: 0.8646 - learning_rate: 1.0000e-04
# Epoch 74/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6045 - loss: 1.2257 - val_accuracy: 0.7510 - val_loss: 0.8514 - learning_rate: 1.0000e-04
# Epoch 75/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6113 - loss: 1.2100 - val_accuracy: 0.7368 - val_loss: 0.8807 - learning_rate: 1.0000e-04
# Epoch 76/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.6129 - loss: 1.2034 - val_accuracy: 0.7461 - val_loss: 0.8502 - learning_rate: 1.0000e-04
# Epoch 77/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6140 - loss: 1.1996 - val_accuracy: 0.7471 - val_loss: 0.8487 - learning_rate: 1.0000e-04
# Epoch 78/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6116 - loss: 1.1912 - val_accuracy: 0.7495 - val_loss: 0.8216 - learning_rate: 1.0000e-04
# Epoch 79/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 49ms/step - accuracy: 0.6155 - loss: 1.1967 - val_accuracy: 0.7392 - val_loss: 0.8593 - learning_rate: 1.0000e-04
# Epoch 80/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 53s 49ms/step - accuracy: 0.6144 - loss: 1.1910 - val_accuracy: 0.7544 - val_loss: 0.8336 - learning_rate: 1.0000e-04
# Epoch 81/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 49ms/step - accuracy: 0.6120 - loss: 1.1882 - val_accuracy: 0.7569 - val_loss: 0.8260 - learning_rate: 1.0000e-04
# Epoch 82/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 49ms/step - accuracy: 0.6211 - loss: 1.1758 - val_accuracy: 0.7520 - val_loss: 0.8337 - learning_rate: 1.0000e-04
# Epoch 83/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 49ms/step - accuracy: 0.6231 - loss: 1.1745 - val_accuracy: 0.7613 - val_loss: 0.8164 - learning_rate: 1.0000e-04
# Epoch 84/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.6228 - loss: 1.1724 - val_accuracy: 0.7554 - val_loss: 0.8150 - learning_rate: 1.0000e-04
# Epoch 85/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.6193 - loss: 1.1795 - val_accuracy: 0.7642 - val_loss: 0.8002 - learning_rate: 1.0000e-04
# Epoch 86/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 54s 50ms/step - accuracy: 0.6250 - loss: 1.1608 - val_accuracy: 0.7588 - val_loss: 0.8151 - learning_rate: 1.0000e-04
# Epoch 87/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 55s 51ms/step - accuracy: 0.6312 - loss: 1.1518 - val_accuracy: 0.7544 - val_loss: 0.8205 - learning_rate: 1.0000e-04
# Epoch 88/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.6256 - loss: 1.1636 - val_accuracy: 0.7534 - val_loss: 0.8221 - learning_rate: 1.0000e-04
# Epoch 89/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 58s 54ms/step - accuracy: 0.6244 - loss: 1.1611 - val_accuracy: 0.7642 - val_loss: 0.8074 - learning_rate: 1.0000e-04
# Epoch 90/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 61s 57ms/step - accuracy: 0.6240 - loss: 1.1606 - val_accuracy: 0.7564 - val_loss: 0.8220 - learning_rate: 1.0000e-04
# Epoch 91/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 60s 55ms/step - accuracy: 0.6247 - loss: 1.1556 - val_accuracy: 0.7676 - val_loss: 0.7891 - learning_rate: 1.0000e-04
# Epoch 92/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 60s 56ms/step - accuracy: 0.6283 - loss: 1.1603 - val_accuracy: 0.7583 - val_loss: 0.8156 - learning_rate: 1.0000e-04
# Epoch 93/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 61s 57ms/step - accuracy: 0.6319 - loss: 1.1445 - val_accuracy: 0.7623 - val_loss: 0.8146 - learning_rate: 1.0000e-04
# Epoch 94/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6373 - loss: 1.1290 - val_accuracy: 0.7627 - val_loss: 0.7922 - learning_rate: 1.0000e-04
# Epoch 95/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6327 - loss: 1.1447 - val_accuracy: 0.7613 - val_loss: 0.8080 - learning_rate: 1.0000e-04
# Epoch 96/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6309 - loss: 1.1296 - val_accuracy: 0.7667 - val_loss: 0.7773 - learning_rate: 1.0000e-04
# Epoch 97/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6368 - loss: 1.1217 - val_accuracy: 0.7598 - val_loss: 0.8029 - learning_rate: 1.0000e-04
# Epoch 98/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6361 - loss: 1.1269 - val_accuracy: 0.7632 - val_loss: 0.7934 - learning_rate: 1.0000e-04
# Epoch 99/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6322 - loss: 1.1324 - val_accuracy: 0.7716 - val_loss: 0.7748 - learning_rate: 1.0000e-04
# Epoch 100/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6375 - loss: 1.1103 - val_accuracy: 0.7608 - val_loss: 0.7945 - learning_rate: 1.0000e-04
# Epoch 101/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6462 - loss: 1.1023 - val_accuracy: 0.7740 - val_loss: 0.7682 - learning_rate: 1.0000e-04
# Epoch 102/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6395 - loss: 1.1113 - val_accuracy: 0.7681 - val_loss: 0.7886 - learning_rate: 1.0000e-04
# Epoch 103/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6400 - loss: 1.1091 - val_accuracy: 0.7740 - val_loss: 0.7687 - learning_rate: 1.0000e-04
# Epoch 104/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6470 - loss: 1.1013 - val_accuracy: 0.7721 - val_loss: 0.7667 - learning_rate: 1.0000e-04
# Epoch 105/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6459 - loss: 1.0919 - val_accuracy: 0.7819 - val_loss: 0.7535 - learning_rate: 1.0000e-04
# Epoch 106/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6460 - loss: 1.1014 - val_accuracy: 0.7569 - val_loss: 0.8105 - learning_rate: 1.0000e-04
# Epoch 107/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6430 - loss: 1.0948 - val_accuracy: 0.7760 - val_loss: 0.7707 - learning_rate: 1.0000e-04
# Epoch 108/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6445 - loss: 1.0880 - val_accuracy: 0.7706 - val_loss: 0.7709 - learning_rate: 1.0000e-04
# Epoch 109/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.6487 - loss: 1.0877 - val_accuracy: 0.7779 - val_loss: 0.7556 - learning_rate: 1.0000e-04
# Epoch 110/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.6494 - loss: 1.0848 - val_accuracy: 0.7789 - val_loss: 0.7501 - learning_rate: 1.0000e-04
# Epoch 111/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.6479 - loss: 1.0945 - val_accuracy: 0.7770 - val_loss: 0.7719 - learning_rate: 1.0000e-04
# Epoch 112/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.6539 - loss: 1.0676 - val_accuracy: 0.7721 - val_loss: 0.7664 - learning_rate: 1.0000e-04
# Epoch 113/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6523 - loss: 1.0809 - val_accuracy: 0.7784 - val_loss: 0.7537 - learning_rate: 1.0000e-04
# Epoch 114/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.6502 - loss: 1.0740 - val_accuracy: 0.7765 - val_loss: 0.7358 - learning_rate: 1.0000e-04
# Epoch 115/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.6505 - loss: 1.0706 - val_accuracy: 0.7740 - val_loss: 0.7503 - learning_rate: 1.0000e-04
# Epoch 116/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.6511 - loss: 1.0630 - val_accuracy: 0.7770 - val_loss: 0.7444 - learning_rate: 1.0000e-04
# Epoch 117/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.6570 - loss: 1.0620 - val_accuracy: 0.7814 - val_loss: 0.7501 - learning_rate: 1.0000e-04
# Epoch 118/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.6583 - loss: 1.0589 - val_accuracy: 0.7672 - val_loss: 0.7731 - learning_rate: 1.0000e-04
# Epoch 119/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.6588 - loss: 1.0457 - val_accuracy: 0.7819 - val_loss: 0.7458 - learning_rate: 1.0000e-04
# Epoch 120/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.6559 - loss: 1.0565 - val_accuracy: 0.7922 - val_loss: 0.7394 - learning_rate: 1.0000e-04
# Epoch 121/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.6632 - loss: 1.0377 - val_accuracy: 0.7838 - val_loss: 0.7374 - learning_rate: 1.0000e-04
# Epoch 122/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6602 - loss: 1.0406 - val_accuracy: 0.7877 - val_loss: 0.7274 - learning_rate: 1.0000e-04
# Epoch 123/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 67s 61ms/step - accuracy: 0.6648 - loss: 1.0336 - val_accuracy: 0.7858 - val_loss: 0.7381 - learning_rate: 1.0000e-04
# Epoch 124/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6601 - loss: 1.0484 - val_accuracy: 0.7897 - val_loss: 0.7244 - learning_rate: 1.0000e-04
# Epoch 125/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6666 - loss: 1.0304 - val_accuracy: 0.7892 - val_loss: 0.7216 - learning_rate: 1.0000e-04
# Epoch 126/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6606 - loss: 1.0417 - val_accuracy: 0.7907 - val_loss: 0.7210 - learning_rate: 1.0000e-04
# Epoch 127/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.6692 - loss: 1.0197 - val_accuracy: 0.7907 - val_loss: 0.7276 - learning_rate: 1.0000e-04
# Epoch 128/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.6666 - loss: 1.0285 - val_accuracy: 0.7907 - val_loss: 0.7119 - learning_rate: 1.0000e-04
# Epoch 129/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6657 - loss: 1.0364 - val_accuracy: 0.7873 - val_loss: 0.7127 - learning_rate: 1.0000e-04
# Epoch 130/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.6698 - loss: 1.0231 - val_accuracy: 0.7863 - val_loss: 0.7438 - learning_rate: 1.0000e-04
# Epoch 131/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6610 - loss: 1.0367 - val_accuracy: 0.7828 - val_loss: 0.7369 - learning_rate: 1.0000e-04
# Epoch 132/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6646 - loss: 1.0220 - val_accuracy: 0.7838 - val_loss: 0.7122 - learning_rate: 1.0000e-04
# Epoch 133/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6712 - loss: 1.0115 - val_accuracy: 0.7882 - val_loss: 0.7141 - learning_rate: 1.0000e-04
# Epoch 134/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6698 - loss: 1.0260 - val_accuracy: 0.7843 - val_loss: 0.7255 - learning_rate: 1.0000e-04
# Epoch 135/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6729 - loss: 1.0018 - val_accuracy: 0.7794 - val_loss: 0.7373 - learning_rate: 1.0000e-04
# Epoch 136/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6679 - loss: 1.0199 - val_accuracy: 0.7946 - val_loss: 0.7047 - learning_rate: 1.0000e-04
# Epoch 137/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6716 - loss: 1.0182 - val_accuracy: 0.7926 - val_loss: 0.7086 - learning_rate: 1.0000e-04
# Epoch 138/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6697 - loss: 1.0145 - val_accuracy: 0.7980 - val_loss: 0.7012 - learning_rate: 1.0000e-04
# Epoch 139/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6708 - loss: 1.0110 - val_accuracy: 0.8025 - val_loss: 0.6843 - learning_rate: 1.0000e-04
# Epoch 140/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6761 - loss: 0.9951 - val_accuracy: 0.7990 - val_loss: 0.7002 - learning_rate: 1.0000e-04
# Epoch 141/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.6755 - loss: 1.0046 - val_accuracy: 0.7868 - val_loss: 0.7217 - learning_rate: 1.0000e-04
# Epoch 142/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6779 - loss: 0.9974 - val_accuracy: 0.7926 - val_loss: 0.7159 - learning_rate: 1.0000e-04
# Epoch 143/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6761 - loss: 0.9937 - val_accuracy: 0.7892 - val_loss: 0.7050 - learning_rate: 1.0000e-04
# Epoch 144/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6760 - loss: 1.0068 - val_accuracy: 0.7863 - val_loss: 0.7042 - learning_rate: 1.0000e-04
# Epoch 145/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6767 - loss: 0.9889 - val_accuracy: 0.7951 - val_loss: 0.6928 - learning_rate: 1.0000e-04
# Epoch 146/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.6757 - loss: 0.9983 - val_accuracy: 0.7936 - val_loss: 0.6873 - learning_rate: 1.0000e-04
# Epoch 147/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6730 - loss: 1.0066 - val_accuracy: 0.7926 - val_loss: 0.6913 - learning_rate: 1.0000e-04
# Epoch 148/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6824 - loss: 0.9788 - val_accuracy: 0.7936 - val_loss: 0.7100 - learning_rate: 1.0000e-04
# Epoch 149/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6808 - loss: 0.9744 - val_accuracy: 0.7966 - val_loss: 0.6816 - learning_rate: 1.0000e-04
# Epoch 150/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6859 - loss: 0.9693 - val_accuracy: 0.7922 - val_loss: 0.7143 - learning_rate: 1.0000e-04
# Epoch 151/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6811 - loss: 0.9792 - val_accuracy: 0.7966 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 152/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.6809 - loss: 0.9780 - val_accuracy: 0.7892 - val_loss: 0.7170 - learning_rate: 1.0000e-04
# Epoch 153/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6865 - loss: 0.9656 - val_accuracy: 0.7961 - val_loss: 0.6864 - learning_rate: 1.0000e-04
# Epoch 154/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6785 - loss: 0.9771 - val_accuracy: 0.7941 - val_loss: 0.7056 - learning_rate: 1.0000e-04
# Epoch 155/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6891 - loss: 0.9615 - val_accuracy: 0.7882 - val_loss: 0.7023 - learning_rate: 1.0000e-04
# Epoch 156/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6904 - loss: 0.9582 - val_accuracy: 0.7946 - val_loss: 0.6983 - learning_rate: 1.0000e-04
# Epoch 157/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6830 - loss: 0.9698 - val_accuracy: 0.7971 - val_loss: 0.6809 - learning_rate: 1.0000e-04
# Epoch 158/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.6851 - loss: 0.9682 - val_accuracy: 0.7912 - val_loss: 0.6911 - learning_rate: 1.0000e-04
# Epoch 159/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6845 - loss: 0.9686 - val_accuracy: 0.8049 - val_loss: 0.6719 - learning_rate: 1.0000e-04
# Epoch 160/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - accuracy: 0.6845 - loss: 0.9616 - val_accuracy: 0.8069 - val_loss: 0.6813 - learning_rate: 1.0000e-04
# Epoch 161/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6897 - loss: 0.9616 - val_accuracy: 0.7951 - val_loss: 0.6985 - learning_rate: 1.0000e-04
# Epoch 162/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6904 - loss: 0.9662 - val_accuracy: 0.7824 - val_loss: 0.7300 - learning_rate: 1.0000e-04
# Epoch 163/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6876 - loss: 0.9632 - val_accuracy: 0.7990 - val_loss: 0.6897 - learning_rate: 1.0000e-04
# Epoch 164/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6911 - loss: 0.9512 - val_accuracy: 0.7956 - val_loss: 0.6982 - learning_rate: 1.0000e-04
# Epoch 165/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6891 - loss: 0.9619 - val_accuracy: 0.8010 - val_loss: 0.6804 - learning_rate: 1.0000e-04
# Epoch 166/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6965 - loss: 0.9401 - val_accuracy: 0.7966 - val_loss: 0.6757 - learning_rate: 1.0000e-04
# Epoch 167/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.6891 - loss: 0.9539 - val_accuracy: 0.7951 - val_loss: 0.7123 - learning_rate: 1.0000e-04
# Epoch 168/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6875 - loss: 0.9633 - val_accuracy: 0.8108 - val_loss: 0.6610 - learning_rate: 1.0000e-04
# Epoch 169/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6949 - loss: 0.9457 - val_accuracy: 0.7917 - val_loss: 0.6863 - learning_rate: 1.0000e-04
# Epoch 170/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6929 - loss: 0.9566 - val_accuracy: 0.8029 - val_loss: 0.6837 - learning_rate: 1.0000e-04
# Epoch 171/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.6983 - loss: 0.9362 - val_accuracy: 0.7863 - val_loss: 0.6968 - learning_rate: 1.0000e-04
# Epoch 172/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.6929 - loss: 0.9494 - val_accuracy: 0.7961 - val_loss: 0.6958 - learning_rate: 1.0000e-04
# Epoch 173/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.6943 - loss: 0.9227 - val_accuracy: 0.8010 - val_loss: 0.6717 - learning_rate: 1.0000e-04
# Epoch 174/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.6953 - loss: 0.9376 - val_accuracy: 0.7951 - val_loss: 0.6975 - learning_rate: 1.0000e-04
# Epoch 175/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 65ms/step - accuracy: 0.6891 - loss: 0.9446 - val_accuracy: 0.8088 - val_loss: 0.6664 - learning_rate: 1.0000e-04
# Epoch 176/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7045 - loss: 0.9204 - val_accuracy: 0.8034 - val_loss: 0.6588 - learning_rate: 1.0000e-04
# Epoch 177/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.7026 - loss: 0.9237 - val_accuracy: 0.8113 - val_loss: 0.6536 - learning_rate: 1.0000e-04
# Epoch 178/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.6969 - loss: 0.9285 - val_accuracy: 0.7995 - val_loss: 0.6799 - learning_rate: 1.0000e-04
# Epoch 179/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.7037 - loss: 0.9200 - val_accuracy: 0.8000 - val_loss: 0.6764 - learning_rate: 1.0000e-04
# Epoch 180/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7010 - loss: 0.9207 - val_accuracy: 0.8020 - val_loss: 0.6828 - learning_rate: 1.0000e-04
# Epoch 181/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7004 - loss: 0.9193 - val_accuracy: 0.8103 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 182/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.6970 - loss: 0.9246 - val_accuracy: 0.8020 - val_loss: 0.6787 - learning_rate: 1.0000e-04
# Epoch 183/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.6955 - loss: 0.9312 - val_accuracy: 0.8000 - val_loss: 0.6896 - learning_rate: 1.0000e-04
# Epoch 184/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.6979 - loss: 0.9238 - val_accuracy: 0.7926 - val_loss: 0.6904 - learning_rate: 1.0000e-04
# Epoch 185/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.6959 - loss: 0.9304 - val_accuracy: 0.7990 - val_loss: 0.6763 - learning_rate: 1.0000e-04
# Epoch 186/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.6975 - loss: 0.9274 - val_accuracy: 0.7980 - val_loss: 0.6854 - learning_rate: 1.0000e-04
# Epoch 187/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7112 - loss: 0.8936 - val_accuracy: 0.8025 - val_loss: 0.6551 - learning_rate: 1.0000e-04
# Epoch 188/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7019 - loss: 0.9189 - val_accuracy: 0.7990 - val_loss: 0.6772 - learning_rate: 1.0000e-04
# Epoch 189/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7038 - loss: 0.9052 - val_accuracy: 0.8108 - val_loss: 0.6653 - learning_rate: 1.0000e-04
# Epoch 190/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7021 - loss: 0.9093 - val_accuracy: 0.8039 - val_loss: 0.6724 - learning_rate: 1.0000e-04
# Epoch 191/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.6978 - loss: 0.9207 - val_accuracy: 0.8015 - val_loss: 0.6723 - learning_rate: 1.0000e-04
# Epoch 192/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7031 - loss: 0.9050 - val_accuracy: 0.8054 - val_loss: 0.6404 - learning_rate: 5.0000e-05
# Epoch 193/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7169 - loss: 0.8679 - val_accuracy: 0.8098 - val_loss: 0.6323 - learning_rate: 5.0000e-05
# Epoch 194/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7151 - loss: 0.8707 - val_accuracy: 0.8108 - val_loss: 0.6280 - learning_rate: 5.0000e-05
# Epoch 195/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7191 - loss: 0.8737 - val_accuracy: 0.8152 - val_loss: 0.6273 - learning_rate: 5.0000e-05
# Epoch 196/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7181 - loss: 0.8703 - val_accuracy: 0.8088 - val_loss: 0.6343 - learning_rate: 5.0000e-05
# Epoch 197/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7202 - loss: 0.8682 - val_accuracy: 0.8098 - val_loss: 0.6388 - learning_rate: 5.0000e-05
# Epoch 198/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7200 - loss: 0.8617 - val_accuracy: 0.8172 - val_loss: 0.6296 - learning_rate: 5.0000e-05
# Epoch 199/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7176 - loss: 0.8658 - val_accuracy: 0.8132 - val_loss: 0.6309 - learning_rate: 5.0000e-05
# Epoch 200/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7188 - loss: 0.8600 - val_accuracy: 0.8034 - val_loss: 0.6363 - learning_rate: 5.0000e-05
# Epoch 201/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7234 - loss: 0.8550 - val_accuracy: 0.8230 - val_loss: 0.6197 - learning_rate: 5.0000e-05
# Epoch 202/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7159 - loss: 0.8751 - val_accuracy: 0.8132 - val_loss: 0.6322 - learning_rate: 5.0000e-05
# Epoch 203/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7207 - loss: 0.8620 - val_accuracy: 0.8176 - val_loss: 0.6205 - learning_rate: 5.0000e-05
# Epoch 204/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7220 - loss: 0.8622 - val_accuracy: 0.8157 - val_loss: 0.6252 - learning_rate: 5.0000e-05
# Epoch 205/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7265 - loss: 0.8560 - val_accuracy: 0.8186 - val_loss: 0.6246 - learning_rate: 5.0000e-05
# Epoch 206/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7216 - loss: 0.8646 - val_accuracy: 0.8235 - val_loss: 0.6117 - learning_rate: 5.0000e-05
# Epoch 207/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7206 - loss: 0.8564 - val_accuracy: 0.8176 - val_loss: 0.6138 - learning_rate: 5.0000e-05
# Epoch 208/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7262 - loss: 0.8533 - val_accuracy: 0.8181 - val_loss: 0.6282 - learning_rate: 5.0000e-05
# Epoch 209/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7247 - loss: 0.8586 - val_accuracy: 0.8230 - val_loss: 0.6118 - learning_rate: 5.0000e-05
# Epoch 210/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7194 - loss: 0.8631 - val_accuracy: 0.8176 - val_loss: 0.6225 - learning_rate: 5.0000e-05
# Epoch 211/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 65ms/step - accuracy: 0.7222 - loss: 0.8502 - val_accuracy: 0.8167 - val_loss: 0.6142 - learning_rate: 5.0000e-05
# Epoch 212/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7232 - loss: 0.8567 - val_accuracy: 0.8255 - val_loss: 0.6149 - learning_rate: 5.0000e-05
# Epoch 213/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7240 - loss: 0.8463 - val_accuracy: 0.8191 - val_loss: 0.6166 - learning_rate: 5.0000e-05
# Epoch 214/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7258 - loss: 0.8579 - val_accuracy: 0.8201 - val_loss: 0.6103 - learning_rate: 5.0000e-05
# Epoch 215/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7264 - loss: 0.8433 - val_accuracy: 0.8225 - val_loss: 0.6133 - learning_rate: 5.0000e-05
# Epoch 216/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7204 - loss: 0.8535 - val_accuracy: 0.8113 - val_loss: 0.6259 - learning_rate: 5.0000e-05
# Epoch 217/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7274 - loss: 0.8459 - val_accuracy: 0.8265 - val_loss: 0.6001 - learning_rate: 5.0000e-05
# Epoch 218/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7235 - loss: 0.8499 - val_accuracy: 0.8201 - val_loss: 0.6100 - learning_rate: 5.0000e-05
# Epoch 219/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7320 - loss: 0.8276 - val_accuracy: 0.8225 - val_loss: 0.6031 - learning_rate: 5.0000e-05
# Epoch 220/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.7244 - loss: 0.8429 - val_accuracy: 0.8211 - val_loss: 0.6113 - learning_rate: 5.0000e-05
# Epoch 221/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7282 - loss: 0.8405 - val_accuracy: 0.8176 - val_loss: 0.6224 - learning_rate: 5.0000e-05
# Epoch 222/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.7287 - loss: 0.8421 - val_accuracy: 0.8191 - val_loss: 0.6165 - learning_rate: 5.0000e-05
# Epoch 223/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7323 - loss: 0.8330 - val_accuracy: 0.8201 - val_loss: 0.6194 - learning_rate: 5.0000e-05
# Epoch 224/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7265 - loss: 0.8403 - val_accuracy: 0.8196 - val_loss: 0.6069 - learning_rate: 5.0000e-05
# Epoch 225/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7290 - loss: 0.8298 - val_accuracy: 0.8235 - val_loss: 0.6079 - learning_rate: 5.0000e-05
# Epoch 226/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7289 - loss: 0.8330 - val_accuracy: 0.8152 - val_loss: 0.6172 - learning_rate: 5.0000e-05
# Epoch 227/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7291 - loss: 0.8331 - val_accuracy: 0.8235 - val_loss: 0.6086 - learning_rate: 5.0000e-05
# Epoch 228/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7350 - loss: 0.8223 - val_accuracy: 0.8275 - val_loss: 0.6006 - learning_rate: 2.5000e-05
# Epoch 229/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7301 - loss: 0.8317 - val_accuracy: 0.8211 - val_loss: 0.6031 - learning_rate: 2.5000e-05
# Epoch 230/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.7352 - loss: 0.8160 - val_accuracy: 0.8245 - val_loss: 0.5984 - learning_rate: 2.5000e-05
# Epoch 231/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7337 - loss: 0.8190 - val_accuracy: 0.8225 - val_loss: 0.5983 - learning_rate: 2.5000e-05
# Epoch 232/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7317 - loss: 0.8211 - val_accuracy: 0.8201 - val_loss: 0.5986 - learning_rate: 2.5000e-05
# Epoch 233/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.7352 - loss: 0.8216 - val_accuracy: 0.8181 - val_loss: 0.6050 - learning_rate: 2.5000e-05
# Epoch 234/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7333 - loss: 0.8230 - val_accuracy: 0.8201 - val_loss: 0.6055 - learning_rate: 2.5000e-05
# Epoch 235/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7398 - loss: 0.8058 - val_accuracy: 0.8201 - val_loss: 0.5999 - learning_rate: 2.5000e-05
# Epoch 236/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7341 - loss: 0.8189 - val_accuracy: 0.8284 - val_loss: 0.5989 - learning_rate: 2.5000e-05
# Epoch 237/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7349 - loss: 0.8164 - val_accuracy: 0.8235 - val_loss: 0.6052 - learning_rate: 2.5000e-05
# Epoch 238/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7371 - loss: 0.8071 - val_accuracy: 0.8225 - val_loss: 0.5958 - learning_rate: 2.5000e-05
# Epoch 239/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7365 - loss: 0.8206 - val_accuracy: 0.8235 - val_loss: 0.5989 - learning_rate: 2.5000e-05
# Epoch 240/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7394 - loss: 0.8080 - val_accuracy: 0.8275 - val_loss: 0.5986 - learning_rate: 2.5000e-05
# Epoch 241/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7441 - loss: 0.8024 - val_accuracy: 0.8235 - val_loss: 0.5999 - learning_rate: 2.5000e-05
# Epoch 242/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7410 - loss: 0.8092 - val_accuracy: 0.8206 - val_loss: 0.6100 - learning_rate: 2.5000e-05
# Epoch 243/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7372 - loss: 0.8060 - val_accuracy: 0.8235 - val_loss: 0.5997 - learning_rate: 2.5000e-05
# Epoch 244/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7378 - loss: 0.8119 - val_accuracy: 0.8275 - val_loss: 0.5960 - learning_rate: 2.5000e-05
# Epoch 245/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7248 - loss: 0.8292 - val_accuracy: 0.8294 - val_loss: 0.6011 - learning_rate: 2.5000e-05
# Epoch 246/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7353 - loss: 0.8146 - val_accuracy: 0.8270 - val_loss: 0.5947 - learning_rate: 2.5000e-05
# Epoch 247/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7363 - loss: 0.8134 - val_accuracy: 0.8250 - val_loss: 0.5996 - learning_rate: 2.5000e-05
# Epoch 248/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7324 - loss: 0.8280 - val_accuracy: 0.8235 - val_loss: 0.5963 - learning_rate: 2.5000e-05
# Epoch 249/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7403 - loss: 0.8080 - val_accuracy: 0.8275 - val_loss: 0.5963 - learning_rate: 2.5000e-05
# Epoch 250/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7429 - loss: 0.7952 - val_accuracy: 0.8235 - val_loss: 0.6001 - learning_rate: 2.5000e-05
# Epoch 251/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7388 - loss: 0.8157 - val_accuracy: 0.8265 - val_loss: 0.6019 - learning_rate: 2.5000e-05
# Epoch 252/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7438 - loss: 0.7929 - val_accuracy: 0.8289 - val_loss: 0.5915 - learning_rate: 2.5000e-05
# Epoch 253/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 70ms/step - accuracy: 0.7398 - loss: 0.7993 - val_accuracy: 0.8255 - val_loss: 0.5922 - learning_rate: 2.5000e-05
# Epoch 254/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7351 - loss: 0.8056 - val_accuracy: 0.8284 - val_loss: 0.5831 - learning_rate: 2.5000e-05
# Epoch 255/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 70ms/step - accuracy: 0.7411 - loss: 0.7988 - val_accuracy: 0.8260 - val_loss: 0.5897 - learning_rate: 2.5000e-05
# Epoch 256/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7344 - loss: 0.8118 - val_accuracy: 0.8284 - val_loss: 0.5884 - learning_rate: 2.5000e-05
# Epoch 257/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 70ms/step - accuracy: 0.7367 - loss: 0.8167 - val_accuracy: 0.8275 - val_loss: 0.5948 - learning_rate: 2.5000e-05
# Epoch 258/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 70ms/step - accuracy: 0.7396 - loss: 0.8118 - val_accuracy: 0.8265 - val_loss: 0.5876 - learning_rate: 2.5000e-05
# Epoch 259/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7376 - loss: 0.8143 - val_accuracy: 0.8314 - val_loss: 0.5856 - learning_rate: 2.5000e-05
# Epoch 260/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7442 - loss: 0.7912 - val_accuracy: 0.8333 - val_loss: 0.5861 - learning_rate: 2.5000e-05
# Epoch 261/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7434 - loss: 0.7919 - val_accuracy: 0.8284 - val_loss: 0.5910 - learning_rate: 2.5000e-05
# Epoch 262/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7431 - loss: 0.7927 - val_accuracy: 0.8289 - val_loss: 0.5946 - learning_rate: 2.5000e-05
# Epoch 263/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.7411 - loss: 0.7959 - val_accuracy: 0.8275 - val_loss: 0.5899 - learning_rate: 2.5000e-05
# Epoch 264/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7403 - loss: 0.7979 - val_accuracy: 0.8284 - val_loss: 0.5950 - learning_rate: 2.5000e-05
# Epoch 265/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7418 - loss: 0.7893 - val_accuracy: 0.8265 - val_loss: 0.5921 - learning_rate: 1.2500e-05
# Epoch 266/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7410 - loss: 0.8031 - val_accuracy: 0.8275 - val_loss: 0.5879 - learning_rate: 1.2500e-05
# Epoch 267/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7433 - loss: 0.7909 - val_accuracy: 0.8275 - val_loss: 0.5823 - learning_rate: 1.2500e-05
# Epoch 268/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7401 - loss: 0.7954 - val_accuracy: 0.8319 - val_loss: 0.5787 - learning_rate: 1.2500e-05
# Epoch 269/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7430 - loss: 0.7928 - val_accuracy: 0.8304 - val_loss: 0.5754 - learning_rate: 1.2500e-05
# Epoch 270/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7393 - loss: 0.8093 - val_accuracy: 0.8314 - val_loss: 0.5783 - learning_rate: 1.2500e-05
# Epoch 271/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7428 - loss: 0.7894 - val_accuracy: 0.8289 - val_loss: 0.5866 - learning_rate: 1.2500e-05
# Epoch 272/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 72s 66ms/step - accuracy: 0.7474 - loss: 0.7857 - val_accuracy: 0.8324 - val_loss: 0.5803 - learning_rate: 1.2500e-05
# Epoch 273/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7527 - loss: 0.7764 - val_accuracy: 0.8284 - val_loss: 0.5775 - learning_rate: 1.2500e-05
# Epoch 274/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 76s 70ms/step - accuracy: 0.7402 - loss: 0.8001 - val_accuracy: 0.8245 - val_loss: 0.5833 - learning_rate: 1.2500e-05
# Epoch 275/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7383 - loss: 0.7987 - val_accuracy: 0.8284 - val_loss: 0.5757 - learning_rate: 1.2500e-05
# Epoch 276/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7490 - loss: 0.7789 - val_accuracy: 0.8250 - val_loss: 0.5813 - learning_rate: 1.2500e-05
# Epoch 277/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7449 - loss: 0.7883 - val_accuracy: 0.8279 - val_loss: 0.5854 - learning_rate: 1.2500e-05
# Epoch 278/300
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 215
#     213 X_other_to_predict = X_other_test[100][np.newaxis, ...]
#     214 y_to_predict = y_test[100]
# --> 215 predict(model, [X_mfcc_to_predict, X_other_to_predict], y_to_predict)
#
# TypeError: predict() missing 1 required positional argument: 'y'

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# Load genre labels
with open(JSON_PATH, "r") as fp:
    genre_labels = json.load(fp)["mapping"]

# ================================================
# Single Sample Prediction
# ================================================
sample_idx = 100
X_mfcc_to_predict = X_mfcc_test[sample_idx]
X_other_to_predict = X_other_test[sample_idx]
y_to_predict = y_test[sample_idx]

# Predict and show results
predicted = model.predict([X_mfcc_to_predict[np.newaxis, ...], 
                         X_other_to_predict[np.newaxis, ...]])
print(f"\nTrue Genre: {genre_labels[y_to_predict]}")
print(f"Predicted Genre: {genre_labels[np.argmax(predicted)]}")
print(f"Confidence: {np.max(predicted) * 100:.2f}%")

# ================================================
# Full Test Set Evaluation
# ================================================
# Generate predictions
y_pred = model.predict([X_mfcc_test, X_other_test])
y_pred_labels = np.argmax(y_pred, axis=1)

# Compute normalized confusion matrix (row-wise)
conf_matrix = confusion_matrix(y_test, y_pred_labels)
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Create plot
plt.figure(figsize=(14, 12))
disp = ConfusionMatrixDisplay(
    confusion_matrix=conf_matrix_norm,
    display_labels=[genre_labels[i] for i in range(len(genre_labels))]
)
disp.plot(
    cmap='Blues',
    ax=plt.gca(),
    xticks_rotation=45,
    values_format='.2f',  # Show 2 decimal places
    colorbar=False
)

# Add custom annotations
for i in range(len(genre_labels)):
    for j in range(len(genre_labels)):
        value = conf_matrix_norm[i, j]
        plt.text(j, i, f"{value:.2f}",
                ha="center", va="center",
                color="white" if value > 0.5 else "black",
                fontsize=10)

# Formatting
plt.title(f" Confusion Matrix\nTest Accuracy: {accuracy_score(y_test, y_pred_labels):.2%}", 
          pad=20, fontsize=14)
plt.xlabel("Predicted Genre", fontsize=12, labelpad=15)
plt.ylabel("True Genre", fontsize=12, labelpad=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()

# Print detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels, 
                           target_names=genre_labels, digits=3))

# Show class distribution
print("\nClass Distribution in Test Set:")
for i, genre in enumerate(genre_labels):
    count = sum(y_test == i)
    if count > 0:
        acc = accuracy_score(y_test[y_test == i], y_pred_labels[y_test == i])
        print(f"{genre:<20}: {acc:.2%} ({count} samples)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# True Genre: Folk
# Predicted Genre: Country
# Confidence: 63.25%
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#              Rock      0.712     0.773     0.742       128
#              Punk      0.822     0.870     0.845       154
#         Post-Rock      0.816     0.884     0.849       146
#        Indie-Rock      0.809     0.809     0.809       157
#        Psych-Rock      0.838     0.722     0.776       158
#        Noise-Rock      0.898     0.876     0.887       170
# Singer-Songwriter      0.680     0.812     0.741       144
#              Folk      0.818     0.750     0.783       144
#        Psych-Folk      0.850     0.744     0.793       160
#           Country      0.758     0.865     0.808       156
#             Blues      0.893     0.856     0.874       146
#             Metal      0.837     0.769     0.801       147
#         Post-Punk      0.814     0.877     0.844       130
#        Industrial      0.835     0.882     0.858       161
#        Freak-Folk      0.892     0.790     0.838       157
#         Krautrock      0.904     0.859     0.881       142
#
#          accuracy                          0.821      2400
#         macro avg      0.824     0.821     0.821      2400
#      weighted avg      0.826     0.821     0.822      2400
#
#
# Class Distribution in Test Set:
# Rock                : 77.34% (128 samples)
# Punk                : 87.01% (154 samples)
# Post-Rock           : 88.36% (146 samples)
# Indie-Rock          : 80.89% (157 samples)
# Psych-Rock          : 72.15% (158 samples)
# Noise-Rock          : 87.65% (170 samples)
# Singer-Songwriter   : 81.25% (144 samples)
# Folk                : 75.00% (144 samples)
# Psych-Folk          : 74.38% (160 samples)
# Country             : 86.54% (156 samples)
# Blues               : 85.62% (146 samples)
# Metal               : 76.87% (147 samples)
# Post-Punk           : 87.69% (130 samples)
# Industrial          : 88.20% (161 samples)
# Freak-Folk          : 78.98% (157 samples)
# Krautrock           : 85.92% (142 samples)

# %%
import json
import os
import math
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tqdm import tqdm
import json
import os
import math
import librosa

# %%
import pandas as pd

# Track counts per genre
genre_counts = {'Rock': 2306,
'Folk' :2288,
'Punk' :1157,
'Indie-Rock' :1086,
'Industrial' :877,
'Blues' :662,
'Post-Rock' :595,
'Singer-Songwriter' :553,
'Psych-Folk' :531,
'Psych-Rock' :397,
'Freak-Folk' :359,
'Post-Punk' :349,
'Country' :295,
'Metal' :241,
'Krautrock' :179,
'Noise-Rock' :174,
}

# Target number of tracks per genre
target_tracks = 100


# Calculate multiplier for each genre
multipliers = {genre: target_tracks / count for genre, count in genre_counts.items()}

# Display the result
multipliers_df = pd.DataFrame(list(multipliers.items()), columns=["Genre", "Multiplier"])
print(multipliers_df)
# Out:
#                 Genre  Multiplier
# 0                Rock    0.043365
# 1                Folk    0.043706
# 2                Punk    0.086430
# 3          Indie-Rock    0.092081
# 4          Industrial    0.114025
# 5               Blues    0.151057
# 6           Post-Rock    0.168067
# 7   Singer-Songwriter    0.180832
# 8          Psych-Folk    0.188324
# 9          Psych-Rock    0.251889
# 10         Freak-Folk    0.278552
# 11          Post-Punk    0.286533
# 12            Country    0.338983
# 13              Metal    0.414938
# 14          Krautrock    0.558659
# 15         Noise-Rock    0.574713
