# %%
import os
import pandas as pd
import librosa
from tqdm import tqdm

METADATA_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/filtered_tracks_metadata.csv'
DATASET_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large'
MIN_SAMPLES = 22050 * 30  # Minimum required samples, e.g., 30 seconds at 22050 Hz

def downsample_tracks(metadata_path, downsample_ratios):
    """
    Downsamples tracks for each genre according to specified ratios in metadata only.

    Parameters:
        metadata_path (str): Path to the custom metadata CSV file.
        downsample_ratios (dict): Dictionary with genres as keys and downsampling factors (0-1) as values.

    Returns:
        DataFrame: Downsampled DataFrame of tracks.
    """
    # Load the metadata file
    tracks = pd.read_csv(metadata_path, index_col=0)

    # Initialize an empty list to store downsampled DataFrames
    downsampled_dfs = []

    # Loop through each genre and apply downsampling
    for genre, ratio in downsample_ratios.items():
        genre_tracks = tracks[tracks['primary_genre'] == genre]

        # Downsample if ratio < 1, otherwise keep all tracks
        if ratio < 1:
            num_samples = int(len(genre_tracks) * ratio)
            genre_tracks_downsampled = genre_tracks.sample(num_samples, random_state=42)
            print(f"Downsampled {genre} from {len(genre_tracks)} to {len(genre_tracks_downsampled)} tracks")
        else:
            genre_tracks_downsampled = genre_tracks
            print(f"Kept all tracks for {genre} (total: {len(genre_tracks)})")

        downsampled_dfs.append(genre_tracks_downsampled)

    # Combine all downsampled DataFrames
    downsampled_tracks = pd.concat(downsampled_dfs)

    # Display the final count of tracks per genre
    print("\nNumber of tracks per genre after downsampling:")
    print(downsampled_tracks['primary_genre'].value_counts())

    return downsampled_tracks

# Define downsampling ratios for each genre
# downsample_ratios = {
#     'Electronic': 0.078,
#     'Avant-Garde': 0.175,
#     'Experimental': 0.2,
#     'Rock': 0.225,
#     'Pop': 0.26,
#     'Folk': 0.35,
#     'Hip-Hop': 0.37,
#     'Punk': 0.42,
#     'Noise': 0.44,
#     'Lo-Fi': 0.55,
#     'Experimental Pop': 0.55,
#     'Ambient Electronic': 0.74,
#     'Jazz': 0.86,
#     'Classical': 0.90,
#     'International': 0.95,
#     'Blues': 1.0,  # Keep all for Blues
# }
downsample_ratios = {
'Experimental'           :0.014,
'Avant-Garde'            :0.0342,
'Rock'                   :0.0449,
'Folk'                   :0.045935,
'Hip-Hop'                :0.049383,
'Blues'                   :0.152,
'Singer-Songwriter'       :0.153,
'Classical'               :0.177620,
'Techno'                  :0.179,
'Jazz'                    :0.195695,
'Reggae - Dub'            :0.337,
'Country'                 :0.341297,
'Metal'                   :0.351,
'Old-Time / Historic'     :0.535,
'New Wave'                :0.568182,
'Novelty'                  :1,
}




# Perform downsampling
downsampled_tracks = downsample_tracks(METADATA_PATH, downsample_ratios)

# Optional: Save the downsampled data to a new CSV
downsampled_tracks.to_csv('downsampled_tracks_metadata.csv')
# Out:
# Downsampled Experimental from 7203 to 100 tracks
# Downsampled Avant-Garde from 2931 to 100 tracks
# Downsampled Rock from 2229 to 100 tracks
# Downsampled Folk from 2177 to 100 tracks
# Downsampled Hip-Hop from 2025 to 100 tracks
# Downsampled Blues from 662 to 100 tracks
# Downsampled Singer-Songwriter from 654 to 100 tracks
# Downsampled Classical from 563 to 100 tracks
# Downsampled Techno from 560 to 100 tracks
# Downsampled Jazz from 511 to 100 tracks
# Downsampled Reggae - Dub from 297 to 100 tracks
# Downsampled Country from 293 to 100 tracks
# Downsampled Metal from 285 to 100 tracks
# Downsampled Old-Time / Historic from 187 to 100 tracks
# Downsampled New Wave from 176 to 100 tracks
# Kept all tracks for Novelty (total: 87)
#
# Number of tracks per genre after downsampling:
# primary_genre
# Experimental           100
# Avant-Garde            100
# Rock                   100
# Folk                   100
# Hip-Hop                100
# Blues                  100
# Singer-Songwriter      100
# Classical              100
# Techno                 100
# Jazz                   100
# Reggae - Dub           100
# Country                100
# Metal                  100
# Old-Time / Historic    100
# New Wave               100
# Novelty                 87
# Name: count, dtype: int64

# %%
import pandas as pd
import os
import librosa
from tqdm import tqdm

# Paths and settings
METADATA_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_metadata/fma_metadata/custom_tracks_metadata.csv'
DATASET_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large'
MIN_SAMPLES = 12000 * 30  # Set the minimum sample threshold (e.g., 30 seconds at 22050 Hz)

def filter_short_tracks(metadata_path, dataset_path, min_samples):
    """
    Filters out tracks with a sample count less than the specified threshold.

    Parameters:
        metadata_path (str): Path to the metadata CSV file.
        dataset_path (str): Path to the directory with audio files.
        min_samples (int): Minimum number of samples required for a track to be included.

    Returns:
        DataFrame: Filtered DataFrame of tracks.
    """
    # Load metadata
    tracks = pd.read_csv(metadata_path, index_col=0)

    # List to store valid track IDs
    valid_tracks = []

    # Progress bar for filtering
    print("Filtering tracks by minimum sample requirement...")
    for track_id in tqdm(tracks.index, desc="Checking track length"):
        folder = f"{int(track_id):03d}"[:3]  # Folder based on track_id
        file_path = os.path.join(dataset_path, folder, f"{track_id}.mp3")

        if os.path.isfile(file_path):
            try:
                # Load audio file and check length
                signal, _ = librosa.load(file_path, sr=None)
                if len(signal) >= min_samples:
                    valid_tracks.append(track_id)  # Track meets minimum sample requirement
            except Exception as e:
                print(f"Error loading {file_path}: {e}")

    # Filter metadata to include only valid tracks
    filtered_tracks = tracks.loc[valid_tracks]

    # Display the final count of tracks per genre
    print("\nNumber of tracks per genre after filtering:")
    print(filtered_tracks['primary_genre'].value_counts())

    return filtered_tracks

# Apply filtering
filtered_tracks = filter_short_tracks(METADATA_PATH, DATASET_PATH, MIN_SAMPLES)

# Optional: Save the filtered data to a new CSV
filtered_tracks.to_csv('filtered_tracks_metadata.csv')
print("Filtered metadata saved to 'filtered_tracks_metadata.csv'.")
# Out:
# Filtering tracks by minimum sample requirement...
# Checking track length:  62%|██████████████████████████████▊                   | 34375/55797 [00:00<00:00, 36762.16it/s]C:\Users\HASSAN\AppData\Local\Temp\ipykernel_27036\3680279564.py:38: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, _ = librosa.load(file_path, sr=None)
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\101\101265.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\101\101272.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\101\101275.mp3:
# Checking track length:  63%|████████████████████████████████▌                   | 34892/55797 [00:20<00:44, 466.77it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\102\102241.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\102\102243.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\102\102247.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\102\102249.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\102\102289.mp3:
# Checking track length:  67%|███████████████████████████████████▌                 | 37385/55797 [02:20<13:01, 23.56it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\109\109266.mp3:
# Checking track length:  68%|███████████████████████████████████▉                 | 37888/55797 [02:43<13:27, 22.19it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\110\110236.mp3:
# Checking track length:  72%|█████████████████████████████████████▉               | 39964/55797 [04:22<13:30, 19.53it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\115\115610.mp3:
# Checking track length:  73%|██████████████████████████████████████▌              | 40561/55797 [04:52<02:53, 88.05it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\117\117441.mp3:
# Checking track length:  80%|██████████████████████████████████████████▏          | 44372/55797 [07:54<09:38, 19.75it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\126\126981.mp3:
# Checking track length:  80%|██████████████████████████████████████████▍          | 44700/55797 [08:11<09:38, 19.17it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\127\127928.mp3:
# Checking track length:  81%|██████████████████████████████████████████▉          | 45237/55797 [08:38<09:15, 19.03it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\129\129207.mp3:
# Checking track length:  82%|███████████████████████████████████████████▏         | 45487/55797 [08:50<08:53, 19.31it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\129\129800.mp3:
# Checking track length:  82%|███████████████████████████████████████████▍         | 45714/55797 [09:01<08:01, 20.92it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\130\130328.mp3:
# Checking track length:  82%|███████████████████████████████████████████▋         | 45961/55797 [09:13<08:38, 18.99it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\130\130748.mp3:
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\130\130751.mp3:
# Checking track length:  84%|████████████████████████████████████████████▋        | 47036/55797 [10:05<07:17, 20.01it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\133\133297.mp3:
# Checking track length:  85%|████████████████████████████████████████████▊        | 47159/55797 [10:11<07:35, 18.98it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\133\133641.mp3:
# Checking track length:  85%|████████████████████████████████████████████▊        | 47165/55797 [10:12<07:40, 18.76it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\133\133647.mp3:
# Checking track length:  91%|████████████████████████████████████████████████▏    | 50721/55797 [13:03<04:00, 21.10it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\142\142614.mp3:
# Checking track length:  92%|████████████████████████████████████████████████▉    | 51486/55797 [13:41<03:35, 20.00it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\143\143992.mp3:
# Checking track length:  95%|██████████████████████████████████████████████████▎  | 52996/55797 [14:55<02:28, 18.83it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\147\147419.mp3:
# Checking track length:  95%|██████████████████████████████████████████████████▎  | 53000/55797 [14:55<02:29, 18.73it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\147\147424.mp3:
# Checking track length: 100%|████████████████████████████████████████████████████▉| 55680/55797 [17:07<00:05, 20.62it/s]
# Error loading C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large\155\155051.mp3:
# Checking track length: 100%|█████████████████████████████████████████████████████| 55797/55797 [17:13<00:00, 53.99it/s]
# Number of tracks per genre after filtering:
# primary_genre
# Experimental           7203
# Avant-Garde            2931
# Rock                   2229
# Folk                   2177
# Hip-Hop                2025
# Blues                   662
# Singer-Songwriter       654
# Classical               563
# Techno                  560
# Jazz                    511
# Reggae - Dub            297
# Country                 293
# Metal                   285
# Old-Time / Historic     187
# New Wave                176
# Novelty                  87
# Name: count, dtype: int64
# Filtered metadata saved to 'filtered_tracks_metadata.csv'.

# %%
import json
import os
import math
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler

# Paths (same as your original)
DATASET_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/fma_large/fma_large'
METADATA_PATH = 'C:/Users/HASSAN/Desktop/Master Thesis/ClasificacionGeneroMusical_DL-master/ClasificacionGeneroMusical_DL-master/downsampled_tracks_metadata.csv' 
JSON_PATH = "data_fma.json"
SAMPLE_RATE = 12000
TRACK_DURATION = 30  # seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

def print_genre_counts(metadata_path, target_genres=None):
    """Same as your original function"""
    tracks = pd.read_csv(metadata_path, index_col=0)
    if target_genres:
        tracks = tracks[tracks['primary_genre'].isin(target_genres)]
        print(f"Filtered tracks by target genres: {len(tracks)}")
    genre_counts = tracks['primary_genre'].value_counts()
    print("\nNumber of tracks per genre:")
    print(genre_counts)

def load_metadata(metadata_path, dataset_path, target_genres=None):
    """Same as your original function"""
    tracks = pd.read_csv(metadata_path, index_col=0)
    if target_genres:
        tracks = tracks[tracks['primary_genre'].isin(target_genres)]
        print(f"Filtered tracks by target genres: {len(tracks)}")

    available_tracks = set()
    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.endswith('.mp3'):
                track_id = int(os.path.splitext(file)[0])
                available_tracks.add(track_id)

    tracks = tracks[tracks.index.isin(available_tracks)]
    print(f"Tracks after file check: {len(tracks)}")
    return tracks['primary_genre'].dropna()

def save_features(dataset_path, json_path, metadata_path, target_genres, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=10):
    """
    Modified version of your save_mfcc() that includes all features while maintaining the same structure
    """
    data = {
        "mapping": target_genres,
        "labels": [],
        "mfcc": [],          # Keeps same structure as original
        "other_features": [] # New: Stores all other features
    }

    genre_data = load_metadata(metadata_path, dataset_path, target_genres)
    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    with tqdm(total=len(genre_data), desc="Processing files", unit="file") as pbar:
        for track_id, genre in genre_data.items():
            folder = f"{int(track_id):03d}"[:3]
            file_path = os.path.join(dataset_path, folder, f"{track_id}.mp3")
            
            if os.path.isfile(file_path):
                try:
                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                    
                    for d in range(num_segments):
                        start = samples_per_segment * d
                        finish = start + samples_per_segment
                        segment = signal[start:finish]
                        
                        if len(segment) < samples_per_segment:
                            segment = np.pad(segment, (0, samples_per_segment - len(segment)), mode='constant')

                        # Extract MFCCs (same as original)
                        mfcc = librosa.feature.mfcc(y=segment, sr=sample_rate,
                                                  n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T
                        
                        # Extract other features (new)
                        other_features = extract_other_features(segment, sample_rate)
                        
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["other_features"].append(other_features)
                            data["labels"].append(target_genres.index(genre))
                        else:
                            print(f"Skipping segment {d} in {file_path} due to unexpected MFCC shape.")

                    pbar.update(1)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
    print(f"\nFeatures saved to {json_path}")

def extract_other_features(segment, sample_rate):
    """Helper function to extract all non-MFCC features"""
    features = []
    
    # Pitch (Yin algorithm)
    try:
        f0 = librosa.yin(segment, fmin=20, fmax=sample_rate//2)
        f0 = f0[f0 > 0]  # Remove zeros
        features.append(float(np.mean(f0)) if len(f0) > 0 else 0.0)
    except:
        features.append(0.0)
    
    # Tempo
    onset_env = librosa.onset.onset_strength(y=segment, sr=sample_rate)
    tempo, _ = librosa.beat.beat_track(onset_envelope=onset_env, sr=sample_rate)
    features.append(float(tempo))
    
    # Beats (mean interval)
    _, beats = librosa.beat.beat_track(onset_envelope=onset_env, sr=sample_rate)
    beats = librosa.frames_to_time(beats, sr=sample_rate)
    if len(beats) > 1:
        features.append(float(np.mean(np.diff(beats))))
    else:
        features.append(0.0)
    
    # Rhythm patterns
    stft = librosa.stft(segment, n_fft=2048, hop_length=512)
    magnitude = np.abs(stft)
    NUM_RHYTHM_BANDS = 6
    band_indices = np.linspace(0, magnitude.shape[0], NUM_RHYTHM_BANDS + 1, dtype=int)
    energy_bands = np.zeros((NUM_RHYTHM_BANDS, magnitude.shape[1]))
    for b in range(NUM_RHYTHM_BANDS):
        energy_bands[b] = np.sum(magnitude[band_indices[b]:band_indices[b+1]], axis=0)
    rhythm_features = []
    for b in range(NUM_RHYTHM_BANDS):
        autocorr = np.correlate(energy_bands[b], energy_bands[b], mode='full')
        rhythm_features.extend(autocorr[len(autocorr)//2:])  # Keep non-negative lags
    features.extend(rhythm_features)
    
    # Chroma features (mean)
    chroma = librosa.feature.chroma_stft(y=segment, sr=sample_rate, n_fft=2048, hop_length=512)
    features.extend(np.mean(chroma, axis=1).tolist())
    
    # RMS dynamics
    rms = librosa.feature.rms(y=segment, frame_length=2048, hop_length=512)[0]
    features.append(float(np.mean(rms)))
    features.append(float(np.std(rms)))
    features.append(float((np.max(rms) - np.min(rms)) / (np.max(rms) + 1e-10)))
    
    return features

def load_data(data_path):
    """Modified to load both MFCCs and other features"""
    with open(data_path, "r") as fp:
        data = json.load(fp)
    
    # MFCCs (same as original)
    X_mfcc = np.array(data["mfcc"])
    
    # Other features (new)
    X_other = np.array(data["other_features"])
    
    y = np.array(data["labels"])
    return X_mfcc, X_other, y

def prepare_datasets(test_size, validation_size):
    """Modified version that maintains your augmentation approach"""
    # Load data
    X_mfcc, X_other, y = load_data(JSON_PATH)
    
    # Split data
    (X_mfcc_train, X_mfcc_test, 
     X_other_train, X_other_test, 
     y_train, y_test) = train_test_split(X_mfcc, X_other, y, test_size=test_size)
    
    (X_mfcc_train, X_mfcc_val, 
     X_other_train, X_other_val, 
     y_train, y_val) = train_test_split(X_mfcc_train, X_other_train, y_train, 
                                      test_size=validation_size)

    # === Data Augmentation (same as your original) ===
    # Reverse MFCCs
    X_mfcc_train_reversed = np.flip(X_mfcc_train, axis=1)
    y_train_reversed = y_train.copy()
    
    # Time shifting
    max_shift = int(0.1 * X_mfcc_train.shape[1])
    X_mfcc_train_shifted = []
    X_other_train_shifted = []
    y_train_shifted = []
    
    for i in range(X_mfcc_train.shape[0]):
        shift = np.random.randint(1, max_shift)
        shifted_mfcc = np.roll(X_mfcc_train[i], shift, axis=1)
        X_mfcc_train_shifted.append(shifted_mfcc)
        X_other_train_shifted.append(X_other_train[i])  # Other features don't get shifted
        y_train_shifted.append(y_train[i])
    
    X_mfcc_train_shifted = np.array(X_mfcc_train_shifted)
    X_other_train_shifted = np.array(X_other_train_shifted)
    y_train_shifted = np.array(y_train_shifted)
    
    # Combine original and augmented data
    X_mfcc_train_augmented = np.concatenate(
        (X_mfcc_train, X_mfcc_train_reversed, X_mfcc_train_shifted), axis=0)
    X_other_train_augmented = np.concatenate(
        (X_other_train, X_other_train, X_other_train_shifted), axis=0)
    y_train_augmented = np.concatenate(
        (y_train, y_train_reversed, y_train_shifted), axis=0)
    
    # Shuffle
    indices = np.arange(X_mfcc_train_augmented.shape[0])
    np.random.shuffle(indices)
    X_mfcc_train_augmented = X_mfcc_train_augmented[indices]
    X_other_train_augmented = X_other_train_augmented[indices]
    y_train_augmented = y_train_augmented[indices]
    
    # Normalize other features
    scaler = StandardScaler()
    X_other_train_augmented = scaler.fit_transform(X_other_train_augmented)
    X_other_val = scaler.transform(X_other_val)
    X_other_test = scaler.transform(X_other_test)
    
    # Add channel dimension to MFCCs
    X_mfcc_train_augmented = X_mfcc_train_augmented[..., np.newaxis]
    X_mfcc_val = X_mfcc_val[..., np.newaxis]
    X_mfcc_test = X_mfcc_test[..., np.newaxis]
    
    return (X_mfcc_train_augmented, X_other_train_augmented), \
           (X_mfcc_val, X_other_val), \
           (X_mfcc_test, X_other_test), \
           y_train_augmented, y_val, y_test

# The rest of your functions (plot_history, predict) remain unchanged

if __name__ == "__main__":
    target_genres = [
        'Experimental', 'Avant-Garde', 'Rock', 'Folk', 'Hip-Hop', 'Blues',
        'Singer-Songwriter', 'Classical', 'Techno', 'Jazz', 'Reggae - Dub', 'Country',
        'Metal', 'Old-Time / Historic', 'New Wave', 'Novelty'
    ]
    
    # Save features (replaces save_mfcc)
    save_features(DATASET_PATH, JSON_PATH, METADATA_PATH, target_genres=target_genres, num_segments=10)
    
    # Prepare datasets
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)
# Out:
# Filtered tracks by target genres: 1587
# Tracks after file check: 1587
# Processing files:   0%|                                                                     | 0/1587 [00:00<?, ?file/s]C:\Users\HASSAN\AppData\Local\Temp\ipykernel_27036\2503193892.py:119: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   features.append(float(tempo))
# Processing files:   0%|                                                             | 3/1587 [00:03<22:24,  1.18file/s]C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# Processing files: 100%|██████████████████████████████████████████████████████████| 1587/1587 [08:56<00:00,  2.96file/s]
# Features saved to data_fma.json

# %%
import json
import os
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization, 
                                    Dropout, Dense, Flatten, Concatenate, Reshape, Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras


def build_hybrid_model(mfcc_shape, other_features_shape, num_classes=16):
    """Hybrid model with original CNN structure for MFCCs and Dense network for other features"""
    # --- CNN Branch (MFCCs) ---
    mfcc_input = Input(shape=mfcc_shape, name='mfcc_input')
    
    # Reshape MFCCs to (time_steps, 13, 1) for Conv2D
    x = Reshape((mfcc_shape[0], mfcc_shape[1], 1))(mfcc_input)
    
    # Original CNN architecture
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = Conv2D(128, (2, 2), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    
    x = Flatten()(x)
    
    # --- Dense Branch (Other Features) ---
    other_input = Input(shape=(other_features_shape,), name='other_input')
    # Layer 1
    y = Dense(64)(other_input)
    y = BatchNormalization()(y)  # BN before activation
    y = Activation('relu')(y)
    y = Dropout(0.2)(y)
    
    # Layer 2 
    y = Dense(128)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Dropout(0.3)(y)
    
    # Layer 3
    y = Dense(128)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Dropout(0.4)(y)
    
    # --- Combine Branches ---
    combined = Concatenate()([x, y])
    
    # Final classification layers
    z = Dense(256, activation='relu')(combined)
    z = Dropout(0.5)(z)
    output = Dense(num_classes, activation='softmax')(z)
    
    return Model(inputs=[mfcc_input, other_input], outputs=output)

def plot_history(history):
    """Plots accuracy/loss for training/validation as a function of the epochs."""
    fig, axs = plt.subplots(2)

    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

def predict(model, X_mfcc, X_other, y):
    """Predict a single sample using the trained model."""
    X_mfcc = X_mfcc[np.newaxis, ...]
    X_other = X_other[np.newaxis, ...]
    prediction = model.predict([X_mfcc, X_other])
    predicted_index = np.argmax(prediction, axis=1)
    print(f"Target: {y}, Predicted label: {predicted_index}")

if __name__ == "__main__":
    # Define target genres
    target_genres = [
        'Experimental', 'Avant-Garde', 'Rock', 'Folk', 'Hip-Hop', 'Blues',
        'Singer-Songwriter', 'Classical', 'Techno', 'Jazz', 'Reggae - Dub', 'Country',
        'Metal', 'Old-Time / Historic', 'New Wave', 'Novelty'
    ]

    # Prepare datasets (using your modified prepare_datasets function)
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)

    # Build model
    mfcc_shape = X_mfcc_train.shape[1:]  # (time_steps, 13)
    other_shape = X_other_train.shape[1]  # num_other_features
    model = build_hybrid_model(mfcc_shape, other_shape)
    
    # Compile with original hyperparameters
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    model.summary()

    # Train with original settings plus early stopping
    history = model.fit(
        [X_mfcc_train, X_other_train], y_train,
        validation_data=([X_mfcc_val, X_other_val], y_val),
        batch_size=32,
        epochs=300,
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
        ]
    )

    # Plot training history
    plot_history(history)

    # Evaluate on test set
    test_loss, test_acc = model.evaluate([X_mfcc_test, X_other_test], y_test, verbose=2)
    print(f"\nTest Accuracy: {test_acc:.4f}")

    # Make a sample prediction
    sample_idx = 100  # Example index
    predict(model, X_mfcc_test[sample_idx], X_other_test[sample_idx], y_test[sample_idx])
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)       │ (None, 71, 13, 1)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 71, 13, 1)         │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 71, 13, 64)        │             640 │ reshape[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ other_input (InputLayer)      │ (None, 444)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 36, 7, 64)         │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64)                │          28,480 │ other_input[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 36, 7, 64)         │             256 │ max_pooling2d[0][0]        │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 64)                │             256 │ dense[0][0]                │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 36, 7, 64)         │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 64)                │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 36, 7, 128)        │          73,856 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 64)                │               0 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 18, 4, 128)        │               0 │ conv2d_1[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │           8,320 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 18, 4, 128)        │             512 │ max_pooling2d_1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 128)               │             512 │ dense_1[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 18, 4, 128)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_1 (Activation)     │ (None, 128)               │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 18, 4, 128)        │          65,664 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 128)               │               0 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 9, 2, 128)         │               0 │ conv2d_2[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 128)               │          16,512 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 9, 2, 128)         │             512 │ max_pooling2d_2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 128)               │             512 │ dense_2[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 9, 2, 128)         │               0 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_2 (Activation)     │ (None, 128)               │               0 │ batch_normalization_5[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2304)              │               0 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 128)               │               0 │ activation_2[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 2432)              │               0 │ flatten[0][0],             │
# │                               │                           │                 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256)               │         622,848 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 256)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 16)                │           4,112 │ dropout_6[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 822,992 (3.14 MB)
#  Trainable params: 821,712 (3.13 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# Epoch 1/300
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['mfcc_input', 'other_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 31s 24ms/step - accuracy: 0.1214 - loss: 3.1553 - val_accuracy: 0.2297 - val_loss: 2.3619
# Epoch 2/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.1980 - loss: 2.4940 - val_accuracy: 0.2520 - val_loss: 2.3211
# Epoch 3/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2312 - loss: 2.3811 - val_accuracy: 0.2619 - val_loss: 2.2833
# Epoch 4/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 25ms/step - accuracy: 0.2588 - loss: 2.3032 - val_accuracy: 0.2747 - val_loss: 2.2626
# Epoch 5/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.2778 - loss: 2.2351 - val_accuracy: 0.2920 - val_loss: 2.2187
# Epoch 6/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.3094 - loss: 2.1589 - val_accuracy: 0.3202 - val_loss: 2.0924
# Epoch 7/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.3129 - loss: 2.1167 - val_accuracy: 0.3192 - val_loss: 2.1435
# Epoch 8/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 25ms/step - accuracy: 0.3274 - loss: 2.0598 - val_accuracy: 0.3365 - val_loss: 2.0866
# Epoch 9/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.
300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.8141 - loss: 0.5465 - val_accuracy: 0.7875 - val_loss: 0.6995
# Epoch 298/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.8194 - loss: 0.5470 - val_accuracy: 0.7885 - val_loss: 0.6851
# Epoch 299/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.8172 - loss: 0.5410 - val_accuracy: 0.7930 - val_loss: 0.6722
# Epoch 300/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 33s 30ms/step - accuracy: 0.8170 - loss: 0.5375 - val_accuracy: 0.7861 - val_loss: 0.6974
# 75/75 - 1s - 9ms/step - accuracy: 0.7971 - loss: 0.7221
#
# Test Accuracy: 0.7971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# Target: 2, Predicted label: [2]

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# Load genre labels
with open(JSON_PATH, "r") as fp:
    genre_labels = json.load(fp)["mapping"]

# ================================================
# Single Sample Prediction
# ================================================
sample_idx = 100
X_mfcc_to_predict = X_mfcc_test[sample_idx]
X_other_to_predict = X_other_test[sample_idx]
y_to_predict = y_test[sample_idx]

# Predict and show results
predicted = model.predict([X_mfcc_to_predict[np.newaxis, ...], 
                         X_other_to_predict[np.newaxis, ...]])
print(f"\nTrue Genre: {genre_labels[y_to_predict]}")
print(f"Predicted Genre: {genre_labels[np.argmax(predicted)]}")
print(f"Confidence: {np.max(predicted) * 100:.2f}%")

# ================================================
# Full Test Set Evaluation
# ================================================
# Generate predictions
y_pred = model.predict([X_mfcc_test, X_other_test])
y_pred_labels = np.argmax(y_pred, axis=1)

# Compute normalized confusion matrix (row-wise)
conf_matrix = confusion_matrix(y_test, y_pred_labels)
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Create plot
plt.figure(figsize=(14, 12))
disp = ConfusionMatrixDisplay(
    confusion_matrix=conf_matrix_norm,
    display_labels=[genre_labels[i] for i in range(len(genre_labels))]
)
disp.plot(
    cmap='Blues',
    ax=plt.gca(),
    xticks_rotation=45,
    values_format='.2f',  # Show 2 decimal places
    colorbar=False
)

# Add custom annotations
for i in range(len(genre_labels)):
    for j in range(len(genre_labels)):
        value = conf_matrix_norm[i, j]
        plt.text(j, i, f"{value:.2f}",
                ha="center", va="center",
                color="white" if value > 0.5 else "black",
                fontsize=10)

# Formatting
plt.title(f"Normalized Confusion Matrix\nTest Accuracy: {accuracy_score(y_test, y_pred_labels):.2%}", 
          pad=20, fontsize=14)
plt.xlabel("Predicted Genre", fontsize=12, labelpad=15)
plt.ylabel("True Genre", fontsize=12, labelpad=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()

# Print detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels, 
                           target_names=genre_labels, digits=3))

# Show class distribution
print("\nClass Distribution in Test Set:")
for i, genre in enumerate(genre_labels):
    count = sum(y_test == i)
    if count > 0:
        acc = accuracy_score(y_test[y_test == i], y_pred_labels[y_test == i])
        print(f"{genre:<20}: {acc:.2%} ({count} samples)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# True Genre: Rock
# Predicted Genre: Rock
# Confidence: 99.74%
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
#        Experimental      0.794     0.712     0.751       146
#         Avant-Garde      0.875     0.757     0.812       148
#                Rock      0.866     0.683     0.764       161
#                Folk      0.746     0.680     0.712       147
#             Hip-Hop      0.699     0.864     0.773       132
#               Blues      0.720     0.771     0.745       140
#   Singer-Songwriter      0.701     0.623     0.660       154
#           Classical      0.831     0.905     0.867       158
#              Techno      0.930     0.881     0.905       151
#                Jazz      0.725     0.739     0.732       157
#        Reggae - Dub      0.804     0.891     0.846       129
#             Country      0.659     0.732     0.693       153
#               Metal      0.838     0.888     0.862       134
# Old-Time / Historic      0.931     0.964     0.947       168
#            New Wave      0.830     0.861     0.845       165
#             Novelty      0.824     0.812     0.818       138
#
#            accuracy                          0.797      2381
#           macro avg      0.798     0.798     0.796      2381
#        weighted avg      0.800     0.797     0.796      2381
#
#
# Class Distribution in Test Set:
# Experimental        : 71.23% (146 samples)
# Avant-Garde         : 75.68% (148 samples)
# Rock                : 68.32% (161 samples)
# Folk                : 68.03% (147 samples)
# Hip-Hop             : 86.36% (132 samples)
# Blues               : 77.14% (140 samples)
# Singer-Songwriter   : 62.34% (154 samples)
# Classical           : 90.51% (158 samples)
# Techno              : 88.08% (151 samples)
# Jazz                : 73.89% (157 samples)
# Reggae - Dub        : 89.15% (129 samples)
# Country             : 73.20% (153 samples)
# Metal               : 88.81% (134 samples)
# Old-Time / Historic : 96.43% (168 samples)
# New Wave            : 86.06% (165 samples)
# Novelty             : 81.16% (138 samples)

# %%
import json
import os
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization, 
                                    Dropout, Dense, Flatten, Concatenate, Reshape,
                                    Bidirectional, GRU, Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras

def build_hybrid_parallel_model(mfcc_shape, other_features_shape, num_classes=16):
    """Hybrid model with CNN+BGRU for MFCCs and Dense network for other features"""
    
    # --- MFCC Input Branch (CNN + BGRU) ---
    mfcc_input = Input(shape=mfcc_shape, name='mfcc_input')
    
    # Reshape MFCCs to (time_steps, 13, 1) for Conv2D
    x = Reshape((mfcc_shape[0], mfcc_shape[1], 1))(mfcc_input)
    
    # --- CNN Branch ---
    cnn_branch = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    cnn_branch = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(cnn_branch)
    cnn_branch = BatchNormalization()(cnn_branch)
    cnn_branch = Dropout(0.2)(cnn_branch)
    
    cnn_branch = Conv2D(128, (3, 3), activation='relu', padding='same')(cnn_branch)
    cnn_branch = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(cnn_branch)
    cnn_branch = BatchNormalization()(cnn_branch)
    cnn_branch = Dropout(0.3)(cnn_branch)
    
    cnn_branch = Conv2D(128, (2, 2), activation='relu', padding='same')(cnn_branch)
    cnn_branch = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(cnn_branch)
    cnn_branch = BatchNormalization()(cnn_branch)
    cnn_branch = Dropout(0.4)(cnn_branch)
    
    cnn_branch = Flatten()(cnn_branch)
    
    # --- BGRU Branch ---
    time_steps = mfcc_shape[0]
    features = mfcc_shape[1]  # 13 MFCC coefficients
    reshaped_mfcc = Reshape((time_steps, features))(mfcc_input)
    
    bgru_branch = Bidirectional(GRU(128, return_sequences=False))(reshaped_mfcc)
    bgru_branch = BatchNormalization()(bgru_branch)
    bgru_branch = Dropout(0.4)(bgru_branch)
    
    
    
    
    # --- Other Features Branch ---
    other_input = Input(shape=(other_features_shape,), name='other_input')
    other_branch = Dense(128)(other_input)
    other_branch = BatchNormalization()(other_branch)  # BN before activation
    other_branch = Activation('relu')(other_branch)
    other_branch = Dropout(0.4)(other_branch)
    
    # Layer 2 
    

    
    # --- Combine All Branches ---
    combined = Concatenate()([cnn_branch, bgru_branch, other_branch])
    
    # Final classification layers
    dense = Dense(256, activation='relu')(combined)
    dense = Dropout(0.5)(dense)
    output = Dense(num_classes, activation='softmax')(dense)
    
    return Model(inputs=[mfcc_input, other_input], outputs=output)

def plot_history(history):
    """Plots accuracy/loss for training/validation as a function of the epochs."""
    fig, axs = plt.subplots(2)

    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

def predict(model, X_mfcc, X_other, y):
    """Predict a single sample using the trained model."""
    X_mfcc = X_mfcc[np.newaxis, ...]
    X_other = X_other[np.newaxis, ...]
    prediction = model.predict([X_mfcc, X_other])
    predicted_index = np.argmax(prediction, axis=1)
    print(f"Target: {y}, Predicted label: {predicted_index}")

if __name__ == "__main__":
    # Define target genres
    target_genres = [
        'Experimental', 'Avant-Garde', 'Rock', 'Folk', 'Hip-Hop', 'Blues',
        'Singer-Songwriter', 'Classical', 'Techno', 'Jazz', 'Reggae - Dub', 'Country',
        'Metal', 'Old-Time / Historic', 'New Wave', 'Novelty'
    ]

    # Prepare datasets (using your modified prepare_datasets function)
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)

    # Build model
    mfcc_shape = X_mfcc_train.shape[1:]  # (time_steps, 13)
    other_shape = X_other_train.shape[1]  # num_other_features
    model = build_hybrid_parallel_model(mfcc_shape, other_shape)
    
    # Compile with original hyperparameters
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    model.summary()

    # Train with original settings plus early stopping
    history = model.fit(
        [X_mfcc_train, X_other_train], y_train,
        validation_data=([X_mfcc_val, X_other_val], y_val),
        batch_size=32,
        epochs=300,
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
        ]
    )

    # Plot training history
    plot_history(history)

    # Evaluate on test set
    test_loss, test_acc = model.evaluate([X_mfcc_test, X_other_test], y_test, verbose=2)
    print(f"\nTest Accuracy: {test_acc:.4f}")

    # Make a sample prediction
    sample_idx = 100  # Example index
    predict(model, X_mfcc_test[sample_idx], X_other_test[sample_idx], y_test[sample_idx])
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)       │ (None, 71, 13, 1)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_1 (Reshape)           │ (None, 71, 13, 1)         │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 71, 13, 64)        │             640 │ reshape_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 36, 7, 64)         │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 36, 7, 64)         │             256 │ max_pooling2d_3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_7 (Dropout)           │ (None, 36, 7, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 36, 7, 128)        │          73,856 │ dropout_7[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 18, 4, 128)        │               0 │ conv2d_4[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 18, 4, 128)        │             512 │ max_pooling2d_4[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_8 (Dropout)           │ (None, 18, 4, 128)        │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 18, 4, 128)        │          65,664 │ dropout_8[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ other_input (InputLayer)      │ (None, 444)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 9, 2, 128)         │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_2 (Reshape)           │ (None, 71, 13)            │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 128)               │          56,960 │ other_input[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 9, 2, 128)         │             512 │ max_pooling2d_5[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional (Bidirectional) │ (None, 256)               │         109,824 │ reshape_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 128)               │             512 │ dense_5[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_9 (Dropout)           │ (None, 9, 2, 128)         │               0 │ batch_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 256)               │           1,024 │ bidirectional[0][0]        │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_3 (Activation)     │ (None, 128)               │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 2304)              │               0 │ dropout_9[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_10 (Dropout)          │ (None, 256)               │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_11 (Dropout)          │ (None, 128)               │               0 │ activation_3[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 2688)              │               0 │ flatten_1[0][0],           │
# │                               │                           │                 │ dropout_10[0][0],          │
# │                               │                           │                 │ dropout_11[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_6 (Dense)               │ (None, 256)               │         688,384 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_12 (Dropout)          │ (None, 256)               │               0 │ dense_6[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_7 (Dense)               │ (None, 16)                │           4,112 │ dropout_12[0][0]           │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,002,256 (3.82 MB)
#  Trainable params: 1,000,848 (3.82 MB)
#  Non-trainable params: 1,408 (5.50 KB)
# Epoch 1/300
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['mfcc_input', 'other_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s
300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 75ms/step - accuracy: 0.8635 - loss: 0.3962 - val_accuracy: 0.8197 - val_loss: 0.6433
# Epoch 286/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.8652 - loss: 0.3969 - val_accuracy: 0.8226 - val_loss: 0.6601
# Epoch 287/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.8690 - loss: 0.3867 - val_accuracy: 0.7994 - val_loss: 0.7178
# Epoch 288/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 75ms/step - accuracy: 0.8638 - loss: 0.3982 - val_accuracy: 0.8216 - val_loss: 0.6550
# Epoch 289/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.8670 - loss: 0.3935 - val_accuracy: 0.8177 - val_loss: 0.6719
# Epoch 290/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.8728 - loss: 0.3767 - val_accuracy: 0.8241 - val_loss: 0.6351
# Epoch 291/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.8699 - loss: 0.3845 - val_accuracy: 0.8157 - val_loss: 0.6706
# Epoch 292/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.8686 - loss: 0.3863 - val_accuracy: 0.8127 - val_loss: 0.6717
# Epoch 293/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.8698 - loss: 0.3852 - val_accuracy: 0.8207 - val_loss: 0.6428
# Epoch 294/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 83s 77ms/step - accuracy: 0.8721 - loss: 0.3830 - val_accuracy: 0.8246 - val_loss: 0.6439
# Epoch 295/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.8737 - loss: 0.3823 - val_accuracy: 0.8167 - val_loss: 0.6600
# Epoch 296/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.8719 - loss: 0.3799 - val_accuracy: 0.8216 - val_loss: 0.6556
# Epoch 297/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.8680 - loss: 0.3847 - val_accuracy: 0.8221 - val_loss: 0.6584
# Epoch 298/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 83s 77ms/step - accuracy: 0.8719 - loss: 0.3719 - val_accuracy: 0.8142 - val_loss: 0.6449
# Epoch 299/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 83s 77ms/step - accuracy: 0.8710 - loss: 0.3805 - val_accuracy: 0.8197 - val_loss: 0.6655
# Epoch 300/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.8691 - loss: 0.3806 - val_accuracy: 0.8221 - val_loss: 0.6441
# 75/75 - 1s - 18ms/step - accuracy: 0.8215 - loss: 0.6865
#
# Test Accuracy: 0.8215
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# Target: 10, Predicted label: [10]

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# Load genre labels
with open(JSON_PATH, "r") as fp:
    genre_labels = json.load(fp)["mapping"]

# ================================================
# Single Sample Prediction
# ================================================
sample_idx = 100
X_mfcc_to_predict = X_mfcc_test[sample_idx]
X_other_to_predict = X_other_test[sample_idx]
y_to_predict = y_test[sample_idx]

# Predict and show results
predicted = model.predict([X_mfcc_to_predict[np.newaxis, ...], 
                         X_other_to_predict[np.newaxis, ...]])
print(f"\nTrue Genre: {genre_labels[y_to_predict]}")
print(f"Predicted Genre: {genre_labels[np.argmax(predicted)]}")
print(f"Confidence: {np.max(predicted) * 100:.2f}%")

# ================================================
# Full Test Set Evaluation
# ================================================
# Generate predictions
y_pred = model.predict([X_mfcc_test, X_other_test])
y_pred_labels = np.argmax(y_pred, axis=1)

# Compute normalized confusion matrix (row-wise)
conf_matrix = confusion_matrix(y_test, y_pred_labels)
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Create plot
plt.figure(figsize=(14, 12))
disp = ConfusionMatrixDisplay(
    confusion_matrix=conf_matrix_norm,
    display_labels=[genre_labels[i] for i in range(len(genre_labels))]
)
disp.plot(
    cmap='Blues',
    ax=plt.gca(),
    xticks_rotation=45,
    values_format='.2f',  # Show 2 decimal places
    colorbar=False
)

# Add custom annotations
for i in range(len(genre_labels)):
    for j in range(len(genre_labels)):
        value = conf_matrix_norm[i, j]
        plt.text(j, i, f"{value:.2f}",
                ha="center", va="center",
                color="white" if value > 0.5 else "black",
                fontsize=10)

# Formatting
plt.title(f"Confusion Matrix\nTest Accuracy: {accuracy_score(y_test, y_pred_labels):.2%}", 
          pad=20, fontsize=14)
plt.xlabel("Predicted Genre", fontsize=12, labelpad=15)
plt.ylabel("True Genre", fontsize=12, labelpad=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()

# Print detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels, 
                           target_names=genre_labels, digits=3))

# Show class distribution
print("\nClass Distribution in Test Set:")
for i, genre in enumerate(genre_labels):
    count = sum(y_test == i)
    if count > 0:
        acc = accuracy_score(y_test[y_test == i], y_pred_labels[y_test == i])
        print(f"{genre:<20}: {acc:.2%} ({count} samples)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# True Genre: Reggae - Dub
# Predicted Genre: Reggae - Dub
# Confidence: 100.00%
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
#        Experimental      0.831     0.778     0.804       158
#         Avant-Garde      0.820     0.769     0.794       130
#                Rock      0.847     0.730     0.784       174
#                Folk      0.742     0.829     0.783       146
#             Hip-Hop      0.750     0.882     0.811       153
#               Blues      0.898     0.777     0.833       148
#   Singer-Songwriter      0.706     0.734     0.720       154
#           Classical      0.867     0.926     0.895       148
#              Techno      0.891     0.874     0.883       159
#                Jazz      0.777     0.743     0.759       136
#        Reggae - Dub      0.817     0.854     0.835       157
#             Country      0.733     0.805     0.767       133
#               Metal      0.848     0.804     0.826       153
# Old-Time / Historic      0.958     0.938     0.948       146
#            New Wave      0.819     0.856     0.837       132
#             Novelty      0.873     0.851     0.862       154
#
#            accuracy                          0.822      2381
#           macro avg      0.824     0.822     0.821      2381
#        weighted avg      0.825     0.822     0.822      2381
#
#
# Class Distribution in Test Set:
# Experimental        : 77.85% (158 samples)
# Avant-Garde         : 76.92% (130 samples)
# Rock                : 72.99% (174 samples)
# Folk                : 82.88% (146 samples)
# Hip-Hop             : 88.24% (153 samples)
# Blues               : 77.70% (148 samples)
# Singer-Songwriter   : 73.38% (154 samples)
# Classical           : 92.57% (148 samples)
# Techno              : 87.42% (159 samples)
# Jazz                : 74.26% (136 samples)
# Reggae - Dub        : 85.35% (157 samples)
# Country             : 80.45% (133 samples)
# Metal               : 80.39% (153 samples)
# Old-Time / Historic : 93.84% (146 samples)
# New Wave            : 85.61% (132 samples)
# Novelty             : 85.06% (154 samples)

# %%
import json
import os
import math
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, GlobalAveragePooling1D, Activation, Concatenate
from tensorflow.keras.layers import PReLU, Layer, BatchNormalization
from tqdm import tqdm
import tensorflow as tf

# Configurations - Added USE_BATCH_NORM flag
class Config:
    MCLNN_LAYER_COUNT = 3
    DENSE_LAYER_COUNT = 2
    TOTAL_LAYER_COUNT = MCLNN_LAYER_COUNT + DENSE_LAYER_COUNT
    HIDDEN_NODES_LIST = [220, 200, 180]
    OTHER_FEATURES_NODES = [128, 64]
    DENSE_NODES = [50, 16]
    MASK_BANDWIDTH = [40, 10, 5]
    MASK_OVERLAP = [-10, 3, 1]
    LAYERS_ORDER_LIST = [4, 4, 4]
    LAYER_IS_MASKED = [True, True, True]
    DROPOUT = [0.01, 0.4, 0.2, 0.1, 0.2]
    OTHER_FEATURES_DROPOUT = [0.15, 0.15]
    WEIGHT_INITIALIZATION = ['he_normal', 'he_normal', 'he_normal', 'glorot_uniform', 'glorot_uniform']
    LEARNING_RATE = 0.0001
    USE_BATCH_NORM = True  # New flag to control batch normalization

# MaskedConditional Layer (unchanged)
class MaskedConditional(Layer):
    def __init__(self, output_dim, init='glorot_uniform', order=5, bandwidth=1, overlap=0, layer_is_masked=True, **kwargs):
        super(MaskedConditional, self).__init__(**kwargs)
        self.output_dim = output_dim
        self.init = keras.initializers.get(init)
        self.order = order
        self.bandwidth = bandwidth
        self.overlap = overlap
        self.layer_is_masked = layer_is_masked

    def build(self, input_shape):
        input_dim = input_shape[-1]
        kernel_size = self.order * 2 + 1
        self.kernel_size = kernel_size

        self.W = self.add_weight(
            shape=(kernel_size, input_dim, self.output_dim),
            initializer=self.init,
            trainable=True,
            name='weights'
        )
        self.b = self.add_weight(
            shape=(self.output_dim,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

        self.weightmask = self.construct_mask(
            input_dim, self.output_dim, self.bandwidth, self.overlap, self.layer_is_masked
        )
        self.weightmask = tf.expand_dims(self.weightmask, axis=0)
        self.weightmask = tf.tile(self.weightmask, [kernel_size, 1, 1])
        self.W.assign(self.W * self.weightmask)

        super(MaskedConditional, self).build(input_shape)

    def construct_mask(self, feature_count, hidden_count, bandwidth, overlap, layer_is_masked):
        bw = bandwidth
        ov = overlap
        l = feature_count
        e = hidden_count

        a = np.arange(1, bw + 1)
        g = np.arange(1, int(np.ceil((l * e) / (l + bw - ov))) + 1)

        if not layer_is_masked:
            binary_mask = np.ones([l, e])
        else:
            mask = np.zeros([l, e])
            flat_matrix = mask.flatten('F')

            for i in range(len(a)):
                for j in range(len(g)):
                    lx = a[i] + (g[j] - 1) * (l + bw - ov)
                    if lx <= l * e:
                        flat_matrix[lx - 1] = 1

            binary_mask = np.transpose(flat_matrix.reshape(e, l))

        return binary_mask.astype(np.float32)

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        sequence_length = tf.shape(inputs)[1]
        feature_count = tf.shape(inputs)[2]

        padding = self.order
        padded_inputs = tf.pad(inputs, [[0, 0], [padding, padding], [0, 0]], mode='CONSTANT')

        outputs = tf.nn.conv1d(padded_inputs, self.W, stride=1, padding='VALID')
        outputs = outputs + self.b
        return outputs

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1], self.output_dim)

# Updated build_parallel_model with BatchNormalization
def build_parallel_model(mfcc_shape, other_features_dim, num_classes=16):
    # MFCC input branch
    mfcc_input = Input(shape=(mfcc_shape[0], mfcc_shape[1]), name='mfcc_input')
    x_mfcc = mfcc_input
    
    # Other features input branch
    other_input = Input(shape=(other_features_dim,), name='other_features_input')
    x_other = other_input
    
    # Process MFCC features through MCLNN layers with BatchNorm
    for layer_index in range(Config.MCLNN_LAYER_COUNT):
        x_mfcc = Dropout(Config.DROPOUT[layer_index])(x_mfcc)
        x_mfcc = MaskedConditional(
            init=Config.WEIGHT_INITIALIZATION[layer_index],
            output_dim=Config.HIDDEN_NODES_LIST[layer_index],
            order=Config.LAYERS_ORDER_LIST[layer_index],
            bandwidth=Config.MASK_BANDWIDTH[layer_index],
            overlap=Config.MASK_OVERLAP[layer_index],
            layer_is_masked=Config.LAYER_IS_MASKED[layer_index]
        )(x_mfcc)
        if Config.USE_BATCH_NORM:
            x_mfcc = BatchNormalization()(x_mfcc)
        x_mfcc = PReLU(shared_axes=[1])(x_mfcc)
    
    # Process other features through dense layers with BatchNorm
    for i, nodes in enumerate(Config.OTHER_FEATURES_NODES):
        x_other = Dropout(Config.OTHER_FEATURES_DROPOUT[i])(x_other)
        x_other = Dense(nodes, activation='relu')(x_other)
        if Config.USE_BATCH_NORM:
            x_other = BatchNormalization()(x_other)
    
    # Global pooling for MFCC features
    mfcc_features = GlobalAveragePooling1D()(x_mfcc)
    
    # Concatenate both feature streams
    combined = Concatenate()([mfcc_features, x_other])
    
    # Add final dense layers with BatchNorm
    for i in range(Config.DENSE_LAYER_COUNT):
        combined = Dropout(Config.DROPOUT[i + Config.MCLNN_LAYER_COUNT])(combined)
        combined = Dense(
            units=Config.DENSE_NODES[i],
            kernel_initializer=Config.WEIGHT_INITIALIZATION[i + Config.MCLNN_LAYER_COUNT]
        )(combined)
        if Config.USE_BATCH_NORM:
            combined = BatchNormalization()(combined)
        if i < Config.DENSE_LAYER_COUNT - 1:
            combined = PReLU()(combined)
        else:
            combined = Activation('softmax')(combined)
    
    model = Model(inputs=[mfcc_input, other_input], outputs=combined)
    optimiser = keras.optimizers.Adam(learning_rate=Config.LEARNING_RATE)
    model.compile(optimizer=optimiser, 
                 loss='sparse_categorical_crossentropy', 
                 metrics=['accuracy'])
    return model

# Main execution remains the same
if __name__ == "__main__":
    # Prepare datasets (now returns both MFCC and other features)
    (X_mfcc_train, X_other_train), (X_mfcc_val, X_other_val), \
    (X_mfcc_test, X_other_test), y_train, y_val, y_test = prepare_datasets(0.15, 0.15)

    # Squeeze the last dimension if it's 1 (remove unnecessary channels dimension)
    X_mfcc_train = X_mfcc_train.squeeze(-1)
    X_mfcc_val = X_mfcc_val.squeeze(-1)
    X_mfcc_test = X_mfcc_test.squeeze(-1)

    print(f"MFCC train shape: {X_mfcc_train.shape}, Other features train shape: {X_other_train.shape}")
    print(f"MFCC val shape: {X_mfcc_val.shape}, Other features val shape: {X_other_val.shape}")

    # Build and compile the model
    mfcc_shape = (X_mfcc_train.shape[1], X_mfcc_train.shape[2])
    other_features_dim = X_other_train.shape[1]
    model = build_parallel_model(mfcc_shape, other_features_dim)
    model.summary()

    # Add callbacks
    callbacks = [
        keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=10)
    ]

    # Train the model
    history = model.fit(
        [X_mfcc_train, X_other_train], y_train,
        validation_data=([X_mfcc_val, X_other_val], y_val),
        batch_size=32,
        epochs=300,
        callbacks=callbacks
    )

    # Evaluate the model on the test set
    test_loss, test_acc = model.evaluate([X_mfcc_test, X_other_test], y_test, verbose=2)
    print(f'\nTest accuracy: {test_acc}')
    plot_history(history)
    
    # Predict a sample from the test set
    X_mfcc_to_predict = X_mfcc_test[100][np.newaxis, ...]
    X_other_to_predict = X_other_test[100][np.newaxis, ...]
    y_to_predict = y_test[100]
    predict(model, [X_mfcc_to_predict, X_other_to_predict], y_to_predict)
# Out:
# MFCC train shape: (34395, 71, 13), Other features train shape: (34395, 444)
# MFCC val shape: (2024, 71, 13), Other features val shape: (2024, 444)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)       │ (None, 71, 13)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_13 (Dropout)          │ (None, 71, 13)            │               0 │ mfcc_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ masked_conditional            │ (None, 71, 220)           │          25,960 │ dropout_13[0][0]           │
# │ (MaskedConditional)           │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 71, 220)           │             880 │ masked_conditional[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu (PReLU)               │ (None, 71, 220)           │             220 │ batch_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_14 (Dropout)          │ (None, 71, 220)           │               0 │ p_re_lu[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ masked_conditional_1          │ (None, 71, 200)           │         396,200 │ dropout_14[0][0]           │
# │ (MaskedConditional)           │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 71, 200)           │             800 │ masked_conditional_1[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ other_features_input          │ (None, 444)               │               0 │ -                          │
# │ (InputLayer)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu_1 (PReLU)             │ (None, 71, 200)           │             200 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_16 (Dropout)          │ (None, 444)               │               0 │ other_features_input[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_15 (Dropout)          │ (None, 71, 200)           │               0 │ p_re_lu_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 128)               │          56,960 │ dropout_16[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ masked_conditional_2          │ (None, 71, 180)           │         324,180 │ dropout_15[0][0]           │
# │ (MaskedConditional)           │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 128)               │             512 │ dense_8[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 71, 180)           │             720 │ masked_conditional_2[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_17 (Dropout)          │ (None, 128)               │               0 │ batch_normalization_14[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu_2 (PReLU)             │ (None, 71, 180)           │             180 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 64)                │           8,256 │ dropout_17[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 180)               │               0 │ p_re_lu_2[0][0]            │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_15        │ (None, 64)                │             256 │ dense_9[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 244)               │               0 │ global_average_pooling1d[… │
# │                               │                           │                 │ batch_normalization_15[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_18 (Dropout)          │ (None, 244)               │               0 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 50)                │          12,250 │ dropout_18[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_16        │ (None, 50)                │             200 │ dense_10[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ p_re_lu_3 (PReLU)             │ (None, 50)                │              50 │ batch_normalization_16[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_19 (Dropout)          │ (None, 50)                │               0 │ p_re_lu_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 16)                │             816 │ dropout_19[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_17        │ (None, 16)                │              64 │ dense_11[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_4 (Activation)     │ (None, 16)                │               0 │ batch_normalization_17[0]… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 828,704 (3.16 MB)
#  Trainable params: 826,988 (3.15 MB)
#  Non-trainable params: 1,716 (6.70 KB)
# Epoch 1/300
# C:\Users\HASSAN\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['mfcc_input', 'other_features_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 60ms/step - accuracy: 0.1771 - loss: 2.6130 - val_accuracy: 0.3207 - val_loss: 2.1468 - learning_rate: 1.0000e-04
# Epoch 2/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.2684 - loss: 2.2836 - val_accuracy: 0.3666 - val_loss: 2.0406 - learning_rate: 1.0000e-04
# Epoch 3/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.3064 - loss: 2.1761 - val_accuracy: 0.4037 - val_loss: 1.9491 - learning_rate: 1.0000e-04
# Epoch 4/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.3285 - loss: 2.1088 - val_accuracy: 0.4190 - val_loss: 1.8970 - learning_rate: 1.0000e-04
# Epoch 5/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.3518 - loss: 2.0595 - val_accuracy: 0.4481 - val_loss: 1.8239 - learning_rate: 1.0000e-04
# Epoch 6/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.3689 - loss: 2.0009 - val_accuracy: 0.4649 - val_loss: 1.7481 - learning_rate: 1.0000e-04
# Epoch 7/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.3832 - loss: 1.9604 - val_accuracy: 0.4531 - val_loss: 1.7325 - learning_rate: 1.0000e-04
# Epoch 8/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.4032 - loss: 1.9005 - val_accuracy: 0.4812 - val_loss: 1.6656 - learning_rate: 1.0000e-04
# Epoch 9/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.4107 - loss: 1.8718 - val_accuracy: 0.5020 - val_loss: 1.6205 - learning_rate: 1.0000e-04
# Epoch 10/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.4235 - loss: 1.8327 - val_accuracy: 0.5321 - val_loss: 1.5680 - learning_rate: 1.0000e-04
# Epoch 11/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.4348 - loss: 1.7968 - val_accuracy: 0.5089 - val_loss: 1.5618 - learning_rate: 1.0000e-04
# Epoch 12/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.4444 - loss: 1.7714 - val_accuracy: 0.5489 - val_loss: 1.4912 - learning_rate: 1.0000e-04
# Epoch 13/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.4600 - loss: 1.7274 - val_accuracy: 0.5543 - val_loss: 1.4739 - learning_rate: 1.0000e-04
# Epoch 14/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.4640 - loss: 1.7074 - val_accuracy: 0.5588 - val_loss: 1.4296 - learning_rate: 1.0000e-04
# Epoch 15/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.4792 - loss: 1.6694 - val_accuracy: 0.5573 - val_loss: 1.4617 - learning_rate: 1.0000e-04
# Epoch 16/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.4796 - loss: 1.6556 - val_accuracy: 0.5662 - val_loss: 1.4086 - learning_rate: 1.0000e-04
# Epoch 17/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.4841 - loss: 1.6313 - val_accuracy: 0.5830 - val_loss: 1.3928 - learning_rate: 1.0000e-04
# Epoch 18/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.4957 - loss: 1.5997 - val_accuracy: 0.5840 - val_loss: 1.3551 - learning_rate: 1.0000e-04
# Epoch 19/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.5053 - loss: 1.5794 - val_accuracy: 0.6126 - val_loss: 1.2917 - learning_rate: 1.0000e-04
# Epoch 20/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.5102 - loss: 1.5635 - val_accuracy: 0.6122 - val_loss: 1.2872 - learning_rate: 1.0000e-04
# Epoch 21/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.5173 - loss: 1.5336 - val_accuracy: 0.6013 - val_loss: 1.2869 - learning_rate: 1.0000e-04
# Epoch 22/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.5292 - loss: 1.5051 - val_accuracy: 0.6225 - val_loss: 1.2228 - learning_rate: 1.0000e-04
# Epoch 23/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.5277 - loss: 1.4962 - val_accuracy: 0.6344 - val_loss: 1.2100 - learning_rate: 1.0000e-04
# Epoch 24/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.5399 - loss: 1.4705 - val_accuracy: 0.6309 - val_loss: 1.1977 - learning_rate: 1.0000e-04
# Epoch 25/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.5417 - loss: 1.4573 - val_accuracy: 0.6502 - val_loss: 1.1563 - learning_rate: 1.0000e-04
# Epoch 26/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.5413 - loss: 1.4463 - val_accuracy: 0.6546 - val_loss: 1.1433 - learning_rate: 1.0000e-04
# Epoch 27/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.5490 - loss: 1.4293 - val_accuracy: 0.6601 - val_loss: 1.1185 - learning_rate: 1.0000e-04
# Epoch 28/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.5557 - loss: 1.4071 - val_accuracy: 0.6502 - val_loss: 1.1302 - learning_rate: 1.0000e-04
# Epoch 29/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.5580 - loss: 1.3881 - val_accuracy: 0.6611 - val_loss: 1.0835 - learning_rate: 1.0000e-04
# Epoch 30/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.5650 - loss: 1.3755 - val_accuracy: 0.6601 - val_loss: 1.0971 - learning_rate: 1.0000e-04
# Epoch 31/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.5685 - loss: 1.3728 - val_accuracy: 0.6714 - val_loss: 1.0706 - learning_rate: 1.0000e-04
# Epoch 32/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.5746 - loss: 1.3490 - val_accuracy: 0.6882 - val_loss: 1.0448 - learning_rate: 1.0000e-04
# Epoch 33/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5796 - loss: 1.3326 - val_accuracy: 0.6754 - val_loss: 1.0423 - learning_rate: 1.0000e-04
# Epoch 34/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5803 - loss: 1.3186 - val_accuracy: 0.6813 - val_loss: 1.0303 - learning_rate: 1.0000e-04
# Epoch 35/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5825 - loss: 1.3065 - val_accuracy: 0.6798 - val_loss: 1.0356 - learning_rate: 1.0000e-04
# Epoch 36/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5871 - loss: 1.2974 - val_accuracy: 0.6971 - val_loss: 0.9944 - learning_rate: 1.0000e-04
# Epoch 37/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5879 - loss: 1.2896 - val_accuracy: 0.7050 - val_loss: 0.9811 - learning_rate: 1.0000e-04
# Epoch 38/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5904 - loss: 1.2853 - val_accuracy: 0.7021 - val_loss: 0.9646 - learning_rate: 1.0000e-04
# Epoch 39/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6065 - loss: 1.2412 - val_accuracy: 0.7001 - val_loss: 0.9712 - learning_rate: 1.0000e-04
# Epoch 40/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.5986 - loss: 1.2562 - val_accuracy: 0.7021 - val_loss: 0.9541 - learning_rate: 1.0000e-04
# Epoch 41/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6017 - loss: 1.2471 - val_accuracy: 0.6833 - val_loss: 0.9849 - learning_rate: 1.0000e-04
# Epoch 42/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.6053 - loss: 1.2338 - val_accuracy: 0.6907 - val_loss: 0.9644 - learning_rate: 1.0000e-04
# Epoch 43/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6159 - loss: 1.2021 - val_accuracy: 0.7233 - val_loss: 0.9376 - learning_rate: 1.0000e-04
# Epoch 44/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6225 - loss: 1.1869 - val_accuracy: 0.7120 - val_loss: 0.9197 - learning_rate: 1.0000e-04
# Epoch 45/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6174 - loss: 1.1942 - val_accuracy: 0.7204 - val_loss: 0.9258 - learning_rate: 1.0000e-04
# Epoch 46/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6202 - loss: 1.1861 - val_accuracy: 0.7332 - val_loss: 0.9155 - learning_rate: 1.0000e-04
# Epoch 47/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6269 - loss: 1.1676 - val_accuracy: 0.7243 - val_loss: 0.8832 - learning_rate: 1.0000e-04
# Epoch 48/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.6226 - loss: 1.1831 - val_accuracy: 0.7223 - val_loss: 0.9071 - learning_rate: 1.0000e-04
# Epoch 49/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6296 - loss: 1.1666 - val_accuracy: 0.7268 - val_loss: 0.8907 - learning_rate: 1.0000e-04
# Epoch 50/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6211 - loss: 1.1718 - val_accuracy: 0.7263 - val_loss: 0.8837 - learning_rate: 1.0000e-04
# Epoch 51/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.6319 - loss: 1.1487 - val_accuracy: 0.7421 - val_loss: 0.8593 - learning_rate: 1.0000e-04
# Epoch 52/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.6297 - loss: 1.1495 - val_accuracy: 0.7342 - val_loss: 0.8852 - learning_rate: 1.0000e-04
# Epoch 53/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6373 - loss: 1.1391 - val_accuracy: 0.7258 - val_loss: 0.8569 - learning_rate: 1.0000e-04
# Epoch 54/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6321 - loss: 1.1323 - val_accuracy: 0.7362 - val_loss: 0.8517 - learning_rate: 1.0000e-04
# Epoch 55/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6425 - loss: 1.1149 - val_accuracy: 0.7411 - val_loss: 0.8437 - learning_rate: 1.0000e-04
# Epoch 56/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6467 - loss: 1.1089 - val_accuracy: 0.7307 - val_loss: 0.8681 - learning_rate: 1.0000e-04
# Epoch 57/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6405 - loss: 1.1154 - val_accuracy: 0.7431 - val_loss: 0.8219 - learning_rate: 1.0000e-04
# Epoch 58/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6537 - loss: 1.0833 - val_accuracy: 0.7500 - val_loss: 0.8356 - learning_rate: 1.0000e-04
# Epoch 59/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6485 - loss: 1.0931 - val_accuracy: 0.7258 - val_loss: 0.8720 - learning_rate: 1.0000e-04
# Epoch 60/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6434 - loss: 1.0907 - val_accuracy: 0.7544 - val_loss: 0.8049 - learning_rate: 1.0000e-04
# Epoch 61/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6490 - loss: 1.0864 - val_accuracy: 0.7495 - val_loss: 0.8213 - learning_rate: 1.0000e-04
# Epoch 62/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6611 - loss: 1.0638 - val_accuracy: 0.7386 - val_loss: 0.8503 - learning_rate: 1.0000e-04
# Epoch 63/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6601 - loss: 1.0657 - val_accuracy: 0.7643 - val_loss: 0.7890 - learning_rate: 1.0000e-04
# Epoch 64/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6587 - loss: 1.0630 - val_accuracy: 0.7633 - val_loss: 0.7866 - learning_rate: 1.0000e-04
# Epoch 65/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 57ms/step - accuracy: 0.6606 - loss: 1.0487 - val_accuracy: 0.7727 - val_loss: 0.7679 - learning_rate: 1.0000e-04
# Epoch 66/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6615 - loss: 1.0507 - val_accuracy: 0.7628 - val_loss: 0.7695 - learning_rate: 1.0000e-04
# Epoch 67/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6691 - loss: 1.0277 - val_accuracy: 0.7722 - val_loss: 0.7570 - learning_rate: 1.0000e-04
# Epoch 68/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6652 - loss: 1.0472 - val_accuracy: 0.7594 - val_loss: 0.7623 - learning_rate: 1.0000e-04
# Epoch 69/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6681 - loss: 1.0336 - val_accuracy: 0.7722 - val_loss: 0.7452 - learning_rate: 1.0000e-04
# Epoch 70/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6636 - loss: 1.0373 - val_accuracy: 0.7683 - val_loss: 0.7717 - learning_rate: 1.0000e-04
# Epoch 71/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.6741 - loss: 1.0204 - val_accuracy: 0.7624 - val_loss: 0.7491 - learning_rate: 1.0000e-04
# Epoch 72/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6771 - loss: 1.0092 - val_accuracy: 0.7663 - val_loss: 0.7392 - learning_rate: 1.0000e-04
# Epoch 73/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6721 - loss: 1.0073 - val_accuracy: 0.7624 - val_loss: 0.7599 - learning_rate: 1.0000e-04
# Epoch 74/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6726 - loss: 1.0058 - val_accuracy: 0.7698 - val_loss: 0.7481 - learning_rate: 1.0000e-04
# Epoch 75/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6772 - loss: 1.0027 - val_accuracy: 0.7633 - val_loss: 0.7443 - learning_rate: 1.0000e-04
# Epoch 76/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6729 - loss: 1.0014 - val_accuracy: 0.7821 - val_loss: 0.7459 - learning_rate: 1.0000e-04
# Epoch 77/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 58ms/step - accuracy: 0.6769 - loss: 0.9972 - val_accuracy: 0.7727 - val_loss: 0.7550 - learning_rate: 1.0000e-04
# Epoch 78/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6771 - loss: 1.0041 - val_accuracy: 0.7708 - val_loss: 0.7595 - learning_rate: 1.0000e-04
# Epoch 79/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6789 - loss: 0.9820 - val_accuracy: 0.7816 - val_loss: 0.7163 - learning_rate: 1.0000e-04
# Epoch 80/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6845 - loss: 0.9687 - val_accuracy: 0.7619 - val_loss: 0.7619 - learning_rate: 1.0000e-04
# Epoch 81/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6806 - loss: 0.9813 - val_accuracy: 0.7703 - val_loss: 0.7500 - learning_rate: 1.0000e-04
# Epoch 82/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6911 - loss: 0.9657 - val_accuracy: 0.7856 - val_loss: 0.7193 - learning_rate: 1.0000e-04
# Epoch 83/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6910 - loss: 0.9622 - val_accuracy: 0.7688 - val_loss: 0.7440 - learning_rate: 1.0000e-04
# Epoch 84/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6918 - loss: 0.9570 - val_accuracy: 0.7816 - val_loss: 0.7121 - learning_rate: 1.0000e-04
# Epoch 85/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.6864 - loss: 0.9599 - val_accuracy: 0.7792 - val_loss: 0.7441 - learning_rate: 1.0000e-04
# Epoch 86/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6873 - loss: 0.9535 - val_accuracy: 0.7708 - val_loss: 0.7332 - learning_rate: 1.0000e-04
# Epoch 87/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6914 - loss: 0.9551 - val_accuracy: 0.7831 - val_loss: 0.7227 - learning_rate: 1.0000e-04
# Epoch 88/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6939 - loss: 0.9523 - val_accuracy: 0.7762 - val_loss: 0.7060 - learning_rate: 1.0000e-04
# Epoch 89/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6900 - loss: 0.9486 - val_accuracy: 0.7826 - val_loss: 0.7106 - learning_rate: 1.0000e-04
# Epoch 90/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 59ms/step - accuracy: 0.6917 - loss: 0.9441 - val_accuracy: 0.7895 - val_loss: 0.6907 - learning_rate: 1.0000e-04
# Epoch 91/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.6987 - loss: 0.9338 - val_accuracy: 0.7688 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 92/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.6971 - loss: 0.9400 - val_accuracy: 0.7915 - val_loss: 0.6883 - learning_rate: 1.0000e-04
# Epoch 93/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.6986 - loss: 0.9205 - val_accuracy: 0.7826 - val_loss: 0.7173 - learning_rate: 1.0000e-04
# Epoch 94/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.7024 - loss: 0.9264 - val_accuracy: 0.7821 - val_loss: 0.6936 - learning_rate: 1.0000e-04
# Epoch 95/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.7005 - loss: 0.9150 - val_accuracy: 0.7895 - val_loss: 0.6899 - learning_rate: 1.0000e-04
# Epoch 96/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.6992 - loss: 0.9179 - val_accuracy: 0.7974 - val_loss: 0.6814 - learning_rate: 1.0000e-04
# Epoch 97/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.7004 - loss: 0.9149 - val_accuracy: 0.7915 - val_loss: 0.6751 - learning_rate: 1.0000e-04
# Epoch 98/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.7001 - loss: 0.9230 - val_accuracy: 0.7945 - val_loss: 0.6644 - learning_rate: 1.0000e-04
# Epoch 99/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.7090 - loss: 0.8993 - val_accuracy: 0.7856 - val_loss: 0.6914 - learning_rate: 1.0000e-04
# Epoch 100/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 60ms/step - accuracy: 0.7041 - loss: 0.8970 - val_accuracy: 0.7880 - val_loss: 0.6810 - learning_rate: 1.0000e-04
# Epoch 101/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.6994 - loss: 0.9159 - val_accuracy: 0.7851 - val_loss: 0.6907 - learning_rate: 1.0000e-04
# Epoch 102/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.7122 - loss: 0.8924 - val_accuracy: 0.7915 - val_loss: 0.6796 - learning_rate: 1.0000e-04
# Epoch 103/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.7095 - loss: 0.8904 - val_accuracy: 0.7871 - val_loss: 0.6911 - learning_rate: 1.0000e-04
# Epoch 104/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.7156 - loss: 0.8841 - val_accuracy: 0.7905 - val_loss: 0.6790 - learning_rate: 1.0000e-04
# Epoch 105/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.7071 - loss: 0.9024 - val_accuracy: 0.7727 - val_loss: 0.7157 - learning_rate: 1.0000e-04
# Epoch 106/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.7124 - loss: 0.8902 - val_accuracy: 0.7950 - val_loss: 0.6625 - learning_rate: 1.0000e-04
# Epoch 107/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7070 - loss: 0.8994 - val_accuracy: 0.7959 - val_loss: 0.6575 - learning_rate: 1.0000e-04
# Epoch 108/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 65s 61ms/step - accuracy: 0.7168 - loss: 0.8759 - val_accuracy: 0.7875 - val_loss: 0.6768 - learning_rate: 1.0000e-04
# Epoch 109/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7151 - loss: 0.8731 - val_accuracy: 0.7955 - val_loss: 0.6697 - learning_rate: 1.0000e-04
# Epoch 110/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7164 - loss: 0.8658 - val_accuracy: 0.7964 - val_loss: 0.6707 - learning_rate: 1.0000e-04
# Epoch 111/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7158 - loss: 0.8656 - val_accuracy: 0.7787 - val_loss: 0.6964 - learning_rate: 1.0000e-04
# Epoch 112/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7175 - loss: 0.8655 - val_accuracy: 0.7989 - val_loss: 0.6341 - learning_rate: 1.0000e-04
# Epoch 113/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7189 - loss: 0.8629 - val_accuracy: 0.8034 - val_loss: 0.6376 - learning_rate: 1.0000e-04
# Epoch 114/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 61ms/step - accuracy: 0.7190 - loss: 0.8628 - val_accuracy: 0.8024 - val_loss: 0.6465 - learning_rate: 1.0000e-04
# Epoch 115/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.7176 - loss: 0.8687 - val_accuracy: 0.7950 - val_loss: 0.6550 - learning_rate: 1.0000e-04
# Epoch 116/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.7152 - loss: 0.8728 - val_accuracy: 0.7945 - val_loss: 0.6543 - learning_rate: 1.0000e-04
# Epoch 117/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 66s 62ms/step - accuracy: 0.7219 - loss: 0.8566 - val_accuracy: 0.7974 - val_loss: 0.6537 - learning_rate: 1.0000e-04
# Epoch 118/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7256 - loss: 0.8428 - val_accuracy: 0.7930 - val_loss: 0.6681 - learning_rate: 1.0000e-04
# Epoch 119/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7163 - loss: 0.8680 - val_accuracy: 0.7969 - val_loss: 0.6745 - learning_rate: 1.0000e-04
# Epoch 120/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7250 - loss: 0.8394 - val_accuracy: 0.7816 - val_loss: 0.6833 - learning_rate: 1.0000e-04
# Epoch 121/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7255 - loss: 0.8422 - val_accuracy: 0.8058 - val_loss: 0.6336 - learning_rate: 1.0000e-04
# Epoch 122/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7269 - loss: 0.8279 - val_accuracy: 0.8034 - val_loss: 0.6264 - learning_rate: 1.0000e-04
# Epoch 123/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7189 - loss: 0.8502 - val_accuracy: 0.7945 - val_loss: 0.6469 - learning_rate: 1.0000e-04
# Epoch 124/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7250 - loss: 0.8441 - val_accuracy: 0.7989 - val_loss: 0.6371 - learning_rate: 1.0000e-04
# Epoch 125/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.7259 - loss: 0.8399 - val_accuracy: 0.7989 - val_loss: 0.6340 - learning_rate: 1.0000e-04
# Epoch 126/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.7319 - loss: 0.8218 - val_accuracy: 0.7994 - val_loss: 0.6312 - learning_rate: 1.0000e-04
# Epoch 127/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 62ms/step - accuracy: 0.7295 - loss: 0.8291 - val_accuracy: 0.7994 - val_loss: 0.6372 - learning_rate: 1.0000e-04
# Epoch 128/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.7291 - loss: 0.8255 - val_accuracy: 0.8043 - val_loss: 0.6234 - learning_rate: 1.0000e-04
# Epoch 129/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.7286 - loss: 0.8264 - val_accuracy: 0.7999 - val_loss: 0.6273 - learning_rate: 1.0000e-04
# Epoch 130/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7400 - loss: 0.8120 - val_accuracy: 0.8103 - val_loss: 0.6242 - learning_rate: 1.0000e-04
# Epoch 131/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7336 - loss: 0.8205 - val_accuracy: 0.7994 - val_loss: 0.6184 - learning_rate: 1.0000e-04
# Epoch 132/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7285 - loss: 0.8351 - val_accuracy: 0.8108 - val_loss: 0.6154 - learning_rate: 1.0000e-04
# Epoch 133/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7338 - loss: 0.8146 - val_accuracy: 0.8063 - val_loss: 0.6182 - learning_rate: 1.0000e-04
# Epoch 134/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7348 - loss: 0.8153 - val_accuracy: 0.8048 - val_loss: 0.6263 - learning_rate: 1.0000e-04
# Epoch 135/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7321 - loss: 0.8264 - val_accuracy: 0.8073 - val_loss: 0.6247 - learning_rate: 1.0000e-04
# Epoch 136/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7316 - loss: 0.8206 - val_accuracy: 0.7994 - val_loss: 0.6394 - learning_rate: 1.0000e-04
# Epoch 137/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7350 - loss: 0.8081 - val_accuracy: 0.8048 - val_loss: 0.6224 - learning_rate: 1.0000e-04
# Epoch 138/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7379 - loss: 0.8009 - val_accuracy: 0.8103 - val_loss: 0.6302 - learning_rate: 1.0000e-04
# Epoch 139/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 64ms/step - accuracy: 0.7403 - loss: 0.8005 - val_accuracy: 0.8043 - val_loss: 0.6272 - learning_rate: 1.0000e-04
# Epoch 140/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 63ms/step - accuracy: 0.7361 - loss: 0.7993 - val_accuracy: 0.8019 - val_loss: 0.6219 - learning_rate: 1.0000e-04
# Epoch 141/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 64ms/step - accuracy: 0.7394 - loss: 0.7994 - val_accuracy: 0.8053 - val_loss: 0.6096 - learning_rate: 1.0000e-04
# Epoch 142/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 68s 64ms/step - accuracy: 0.7429 - loss: 0.7867 - val_accuracy: 0.8127 - val_loss: 0.6108 - learning_rate: 1.0000e-04
# Epoch 143/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7389 - loss: 0.7895 - val_accuracy: 0.7974 - val_loss: 0.6295 - learning_rate: 1.0000e-04
# Epoch 144/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7477 - loss: 0.7831 - val_accuracy: 0.8009 - val_loss: 0.6117 - learning_rate: 1.0000e-04
# Epoch 145/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7398 - loss: 0.7941 - val_accuracy: 0.8029 - val_loss: 0.6151 - learning_rate: 1.0000e-04
# Epoch 146/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7466 - loss: 0.7851 - val_accuracy: 0.8083 - val_loss: 0.5991 - learning_rate: 1.0000e-04
# Epoch 147/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7460 - loss: 0.7877 - val_accuracy: 0.8113 - val_loss: 0.5919 - learning_rate: 1.0000e-04
# Epoch 148/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7451 - loss: 0.7837 - val_accuracy: 0.8088 - val_loss: 0.6127 - learning_rate: 1.0000e-04
# Epoch 149/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7501 - loss: 0.7740 - val_accuracy: 0.8088 - val_loss: 0.6179 - learning_rate: 1.0000e-04
# Epoch 150/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7458 - loss: 0.7725 - val_accuracy: 0.7984 - val_loss: 0.6508 - learning_rate: 1.0000e-04
# Epoch 151/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7458 - loss: 0.7805 - val_accuracy: 0.8103 - val_loss: 0.6169 - learning_rate: 1.0000e-04
# Epoch 152/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 64ms/step - accuracy: 0.7529 - loss: 0.7663 - val_accuracy: 0.8108 - val_loss: 0.5886 - learning_rate: 1.0000e-04
# Epoch 153/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 65ms/step - accuracy: 0.7412 - loss: 0.7747 - val_accuracy: 0.8182 - val_loss: 0.5853 - learning_rate: 1.0000e-04
# Epoch 154/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 69s 65ms/step - accuracy: 0.7515 - loss: 0.7604 - val_accuracy: 0.8132 - val_loss: 0.5957 - learning_rate: 1.0000e-04
# Epoch 155/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7452 - loss: 0.7812 - val_accuracy: 0.8197 - val_loss: 0.6057 - learning_rate: 1.0000e-04
# Epoch 156/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7479 - loss: 0.7619 - val_accuracy: 0.8078 - val_loss: 0.6033 - learning_rate: 1.0000e-04
# Epoch 157/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7530 - loss: 0.7655 - val_accuracy: 0.8039 - val_loss: 0.6082 - learning_rate: 1.0000e-04
# Epoch 158/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7492 - loss: 0.7556 - val_accuracy: 0.8211 - val_loss: 0.5903 - learning_rate: 1.0000e-04
# Epoch 159/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7535 - loss: 0.7569 - val_accuracy: 0.8063 - val_loss: 0.6184 - learning_rate: 1.0000e-04
# Epoch 160/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7541 - loss: 0.7535 - val_accuracy: 0.8103 - val_loss: 0.6109 - learning_rate: 1.0000e-04
# Epoch 161/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7545 - loss: 0.7560 - val_accuracy: 0.8083 - val_loss: 0.6175 - learning_rate: 1.0000e-04
# Epoch 162/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7522 - loss: 0.7605 - val_accuracy: 0.8118 - val_loss: 0.5944 - learning_rate: 1.0000e-04
# Epoch 163/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 65ms/step - accuracy: 0.7529 - loss: 0.7559 - val_accuracy: 0.8093 - val_loss: 0.6049 - learning_rate: 1.0000e-04
# Epoch 164/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 70s 66ms/step - accuracy: 0.7660 - loss: 0.7251 - val_accuracy: 0.8271 - val_loss: 0.5775 - learning_rate: 5.0000e-05
# Epoch 165/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7659 - loss: 0.7182 - val_accuracy: 0.8192 - val_loss: 0.5703 - learning_rate: 5.0000e-05
# Epoch 166/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7610 - loss: 0.7254 - val_accuracy: 0.8197 - val_loss: 0.5731 - learning_rate: 5.0000e-05
# Epoch 167/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7649 - loss: 0.7228 - val_accuracy: 0.8216 - val_loss: 0.5741 - learning_rate: 5.0000e-05
# Epoch 168/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7699 - loss: 0.7083 - val_accuracy: 0.8241 - val_loss: 0.5691 - learning_rate: 5.0000e-05
# Epoch 169/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7694 - loss: 0.7032 - val_accuracy: 0.8256 - val_loss: 0.5733 - learning_rate: 5.0000e-05
# Epoch 170/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7684 - loss: 0.7055 - val_accuracy: 0.8221 - val_loss: 0.5712 - learning_rate: 5.0000e-05
# Epoch 171/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7688 - loss: 0.7034 - val_accuracy: 0.8246 - val_loss: 0.5609 - learning_rate: 5.0000e-05
# Epoch 172/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7679 - loss: 0.7107 - val_accuracy: 0.8241 - val_loss: 0.5460 - learning_rate: 5.0000e-05
# Epoch 173/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7668 - loss: 0.7133 - val_accuracy: 0.8236 - val_loss: 0.5529 - learning_rate: 5.0000e-05
# Epoch 174/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7736 - loss: 0.6954 - val_accuracy: 0.8187 - val_loss: 0.5710 - learning_rate: 5.0000e-05
# Epoch 175/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7707 - loss: 0.7002 - val_accuracy: 0.8325 - val_loss: 0.5541 - learning_rate: 5.0000e-05
# Epoch 176/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 71s 66ms/step - accuracy: 0.7737 - loss: 0.6976 - val_accuracy: 0.8246 - val_loss: 0.5529 - learning_rate: 5.0000e-05
# Epoch 177/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7691 - loss: 0.7092 - val_accuracy: 0.8226 - val_loss: 0.5631 - learning_rate: 5.0000e-05
# Epoch 178/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7709 - loss: 0.7096 - val_accuracy: 0.8246 - val_loss: 0.5615 - learning_rate: 5.0000e-05
# Epoch 179/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7778 - loss: 0.6783 - val_accuracy: 0.8286 - val_loss: 0.5485 - learning_rate: 5.0000e-05
# Epoch 180/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7714 - loss: 0.7126 - val_accuracy: 0.8246 - val_loss: 0.5515 - learning_rate: 5.0000e-05
# Epoch 181/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7729 - loss: 0.6845 - val_accuracy: 0.8241 - val_loss: 0.5627 - learning_rate: 5.0000e-05
# Epoch 182/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7734 - loss: 0.6970 - val_accuracy: 0.8300 - val_loss: 0.5486 - learning_rate: 5.0000e-05
# Epoch 183/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7787 - loss: 0.6831 - val_accuracy: 0.8256 - val_loss: 0.5504 - learning_rate: 2.5000e-05
# Epoch 184/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7795 - loss: 0.6808 - val_accuracy: 0.8345 - val_loss: 0.5387 - learning_rate: 2.5000e-05
# Epoch 185/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7786 - loss: 0.6781 - val_accuracy: 0.8286 - val_loss: 0.5401 - learning_rate: 2.5000e-05
# Epoch 186/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7786 - loss: 0.6801 - val_accuracy: 0.8295 - val_loss: 0.5329 - learning_rate: 2.5000e-05
# Epoch 187/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7807 - loss: 0.6722 - val_accuracy: 0.8221 - val_loss: 0.5479 - learning_rate: 2.5000e-05
# Epoch 188/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.7801 - loss: 0.6744 - val_accuracy: 0.8365 - val_loss: 0.5351 - learning_rate: 2.5000e-05
# Epoch 189/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 67ms/step - accuracy: 0.7851 - loss: 0.6676 - val_accuracy: 0.8266 - val_loss: 0.5468 - learning_rate: 2.5000e-05
# Epoch 190/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7796 - loss: 0.6737 - val_accuracy: 0.8315 - val_loss: 0.5400 - learning_rate: 2.5000e-05
# Epoch 191/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7774 - loss: 0.6838 - val_accuracy: 0.8315 - val_loss: 0.5272 - learning_rate: 2.5000e-05
# Epoch 192/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7784 - loss: 0.6763 - val_accuracy: 0.8330 - val_loss: 0.5395 - learning_rate: 2.5000e-05
# Epoch 193/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7857 - loss: 0.6589 - val_accuracy: 0.8291 - val_loss: 0.5396 - learning_rate: 2.5000e-05
# Epoch 194/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7879 - loss: 0.6620 - val_accuracy: 0.8320 - val_loss: 0.5495 - learning_rate: 2.5000e-05
# Epoch 195/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7794 - loss: 0.6714 - val_accuracy: 0.8300 - val_loss: 0.5503 - learning_rate: 2.5000e-05
# Epoch 196/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7825 - loss: 0.6703 - val_accuracy: 0.8330 - val_loss: 0.5306 - learning_rate: 2.5000e-05
# Epoch 197/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7808 - loss: 0.6711 - val_accuracy: 0.8325 - val_loss: 0.5447 - learning_rate: 2.5000e-05
# Epoch 198/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7847 - loss: 0.6538 - val_accuracy: 0.8325 - val_loss: 0.5360 - learning_rate: 2.5000e-05
# Epoch 199/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.7838 - loss: 0.6594 - val_accuracy: 0.8345 - val_loss: 0.5357 - learning_rate: 2.5000e-05
# Epoch 200/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7864 - loss: 0.6602 - val_accuracy: 0.8355 - val_loss: 0.5258 - learning_rate: 2.5000e-05
# Epoch 201/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7844 - loss: 0.6636 - val_accuracy: 0.8340 - val_loss: 0.5229 - learning_rate: 2.5000e-05
# Epoch 202/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.7871 - loss: 0.6545 - val_accuracy: 0.8345 - val_loss: 0.5358 - learning_rate: 2.5000e-05
# Epoch 203/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7834 - loss: 0.6691 - val_accuracy: 0.8355 - val_loss: 0.5336 - learning_rate: 2.5000e-05
# Epoch 204/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7861 - loss: 0.6642 - val_accuracy: 0.8340 - val_loss: 0.5341 - learning_rate: 2.5000e-05
# Epoch 205/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7834 - loss: 0.6606 - val_accuracy: 0.8384 - val_loss: 0.5297 - learning_rate: 2.5000e-05
# Epoch 206/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7876 - loss: 0.6564 - val_accuracy: 0.8330 - val_loss: 0.5295 - learning_rate: 2.5000e-05
# Epoch 207/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7864 - loss: 0.6638 - val_accuracy: 0.8340 - val_loss: 0.5270 - learning_rate: 2.5000e-05
# Epoch 208/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.7835 - loss: 0.6595 - val_accuracy: 0.8404 - val_loss: 0.5404 - learning_rate: 2.5000e-05
# Epoch 209/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7845 - loss: 0.6552 - val_accuracy: 0.8379 - val_loss: 0.5273 - learning_rate: 2.5000e-05
# Epoch 210/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7854 - loss: 0.6616 - val_accuracy: 0.8310 - val_loss: 0.5350 - learning_rate: 2.5000e-05
# Epoch 211/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7851 - loss: 0.6717 - val_accuracy: 0.8350 - val_loss: 0.5297 - learning_rate: 2.5000e-05
# Epoch 212/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7886 - loss: 0.6526 - val_accuracy: 0.8379 - val_loss: 0.5289 - learning_rate: 1.2500e-05
# Epoch 213/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.7921 - loss: 0.6450 - val_accuracy: 0.8335 - val_loss: 0.5381 - learning_rate: 1.2500e-05
# Epoch 214/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7883 - loss: 0.6551 - val_accuracy: 0.8350 - val_loss: 0.5238 - learning_rate: 1.2500e-05
# Epoch 215/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7845 - loss: 0.6612 - val_accuracy: 0.8375 - val_loss: 0.5236 - learning_rate: 1.2500e-05
# Epoch 216/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7857 - loss: 0.6615 - val_accuracy: 0.8335 - val_loss: 0.5225 - learning_rate: 1.2500e-05
# Epoch 217/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7868 - loss: 0.6495 - val_accuracy: 0.8335 - val_loss: 0.5218 - learning_rate: 1.2500e-05
# Epoch 218/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 70ms/step - accuracy: 0.7899 - loss: 0.6510 - val_accuracy: 0.8399 - val_loss: 0.5232 - learning_rate: 1.2500e-05
# Epoch 219/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7857 - loss: 0.6510 - val_accuracy: 0.8379 - val_loss: 0.5294 - learning_rate: 1.2500e-05
# Epoch 220/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7872 - loss: 0.6452 - val_accuracy: 0.8384 - val_loss: 0.5274 - learning_rate: 1.2500e-05
# Epoch 221/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7857 - loss: 0.6586 - val_accuracy: 0.8365 - val_loss: 0.5209 - learning_rate: 1.2500e-05
# Epoch 222/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7812 - loss: 0.6629 - val_accuracy: 0.8394 - val_loss: 0.5211 - learning_rate: 1.2500e-05
# Epoch 223/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7891 - loss: 0.6441 - val_accuracy: 0.8355 - val_loss: 0.5271 - learning_rate: 1.2500e-05
# Epoch 224/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7843 - loss: 0.6617 - val_accuracy: 0.8375 - val_loss: 0.5260 - learning_rate: 1.2500e-05
# Epoch 225/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7904 - loss: 0.6438 - val_accuracy: 0.8379 - val_loss: 0.5178 - learning_rate: 1.2500e-05
# Epoch 226/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7937 - loss: 0.6381 - val_accuracy: 0.8414 - val_loss: 0.5192 - learning_rate: 1.2500e-05
# Epoch 227/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7860 - loss: 0.6517 - val_accuracy: 0.8379 - val_loss: 0.5265 - learning_rate: 1.2500e-05
# Epoch 228/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7963 - loss: 0.6324 - val_accuracy: 0.8335 - val_loss: 0.5236 - learning_rate: 1.2500e-05
# Epoch 229/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7919 - loss: 0.6431 - val_accuracy: 0.8335 - val_loss: 0.5288 - learning_rate: 1.2500e-05
# Epoch 230/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7922 - loss: 0.6428 - val_accuracy: 0.8350 - val_loss: 0.5268 - learning_rate: 1.2500e-05
# Epoch 231/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7892 - loss: 0.6506 - val_accuracy: 0.8379 - val_loss: 0.5278 - learning_rate: 1.2500e-05
# Epoch 232/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7914 - loss: 0.6419 - val_accuracy: 0.8394 - val_loss: 0.5195 - learning_rate: 1.2500e-05
# Epoch 233/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 76s 71ms/step - accuracy: 0.7919 - loss: 0.6408 - val_accuracy: 0.8345 - val_loss: 0.5324 - learning_rate: 1.2500e-05
# Epoch 234/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7929 - loss: 0.6434 - val_accuracy: 0.8404 - val_loss: 0.5249 - learning_rate: 1.2500e-05
# Epoch 235/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7951 - loss: 0.6368 - val_accuracy: 0.8379 - val_loss: 0.5251 - learning_rate: 1.2500e-05
# Epoch 236/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7911 - loss: 0.6450 - val_accuracy: 0.8394 - val_loss: 0.5217 - learning_rate: 6.2500e-06
# Epoch 237/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7909 - loss: 0.6367 - val_accuracy: 0.8399 - val_loss: 0.5245 - learning_rate: 6.2500e-06
# Epoch 238/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7925 - loss: 0.6375 - val_accuracy: 0.8404 - val_loss: 0.5217 - learning_rate: 6.2500e-06
# Epoch 239/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7953 - loss: 0.6374 - val_accuracy: 0.8389 - val_loss: 0.5149 - learning_rate: 6.2500e-06
# Epoch 240/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7931 - loss: 0.6292 - val_accuracy: 0.8399 - val_loss: 0.5162 - learning_rate: 6.2500e-06
# Epoch 241/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.7867 - loss: 0.6393 - val_accuracy: 0.8389 - val_loss: 0.5252 - learning_rate: 6.2500e-06
# Epoch 242/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7895 - loss: 0.6461 - val_accuracy: 0.8365 - val_loss: 0.5217 - learning_rate: 6.2500e-06
# Epoch 243/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7926 - loss: 0.6326 - val_accuracy: 0.8370 - val_loss: 0.5194 - learning_rate: 6.2500e-06
# Epoch 244/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7889 - loss: 0.6493 - val_accuracy: 0.8389 - val_loss: 0.5150 - learning_rate: 6.2500e-06
# Epoch 245/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7871 - loss: 0.6426 - val_accuracy: 0.8399 - val_loss: 0.5236 - learning_rate: 6.2500e-06
# Epoch 246/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7866 - loss: 0.6489 - val_accuracy: 0.8414 - val_loss: 0.5164 - learning_rate: 6.2500e-06
# Epoch 247/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.7932 - loss: 0.6439 - val_accuracy: 0.8384 - val_loss: 0.5175 - learning_rate: 6.2500e-06
# Epoch 248/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.7914 - loss: 0.6395 - val_accuracy: 0.8355 - val_loss: 0.5204 - learning_rate: 6.2500e-06
# Epoch 249/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 9734s 9s/step - accuracy: 0.7952 - loss: 0.6327 - val_accuracy: 0.8414 - val_loss: 0.5061 - learning_rate: 7.8125e-07
# Epoch 297/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.7914 - loss: 0.6399 - val_accuracy: 0.8419 - val_loss: 0.5093 - learning_rate: 7.8125e-07
# Epoch 298/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 83s 77ms/step - accuracy: 0.7928 - loss: 0.6275 - val_accuracy: 0.8389 - val_loss: 0.5175 - learning_rate: 7.8125e-07
# Epoch 299/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 85s 79ms/step - accuracy: 0.7948 - loss: 0.6275 - val_accuracy: 0.8394 - val_loss: 0.5142 - learning_rate: 7.8125e-07
# Epoch 300/300
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 84s 78ms/step - accuracy: 0.7967 - loss: 0.6223 - val_accuracy: 0.8365 - val_loss: 0.5167 - learning_rate: 7.8125e-07
# 75/75 - 2s - 22ms/step - accuracy: 0.8387 - loss: 0.5337
#
# Test accuracy: 0.8387232422828674
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 215
#     213 X_other_to_predict = X_other_test[100][np.newaxis, ...]
#     214 y_to_predict = y_test[100]
# --> 215 predict(model, [X_mfcc_to_predict, X_other_to_predict], y_to_predict)
#
# TypeError: predict() missing 1 required positional argument: 'y'

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# Load genre labels
with open(JSON_PATH, "r") as fp:
    genre_labels = json.load(fp)["mapping"]

# ================================================
# Single Sample Prediction
# ================================================
sample_idx = 100
X_mfcc_to_predict = X_mfcc_test[sample_idx]
X_other_to_predict = X_other_test[sample_idx]
y_to_predict = y_test[sample_idx]

# Predict and show results
predicted = model.predict([X_mfcc_to_predict[np.newaxis, ...], 
                         X_other_to_predict[np.newaxis, ...]])
print(f"\nTrue Genre: {genre_labels[y_to_predict]}")
print(f"Predicted Genre: {genre_labels[np.argmax(predicted)]}")
print(f"Confidence: {np.max(predicted) * 100:.2f}%")

# ================================================
# Full Test Set Evaluation
# ================================================
# Generate predictions
y_pred = model.predict([X_mfcc_test, X_other_test])
y_pred_labels = np.argmax(y_pred, axis=1)

# Compute normalized confusion matrix (row-wise)
conf_matrix = confusion_matrix(y_test, y_pred_labels)
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Create plot
plt.figure(figsize=(14, 12))
disp = ConfusionMatrixDisplay(
    confusion_matrix=conf_matrix_norm,
    display_labels=[genre_labels[i] for i in range(len(genre_labels))]
)
disp.plot(
    cmap='Blues',
    ax=plt.gca(),
    xticks_rotation=45,
    values_format='.2f',  # Show 2 decimal places
    colorbar=False
)

# Add custom annotations
for i in range(len(genre_labels)):
    for j in range(len(genre_labels)):
        value = conf_matrix_norm[i, j]
        plt.text(j, i, f"{value:.2f}",
                ha="center", va="center",
                color="white" if value > 0.5 else "black",
                fontsize=10)

# Formatting
plt.title(f"Confusion Matrix\nTest Accuracy: {accuracy_score(y_test, y_pred_labels):.2%}", 
          pad=20, fontsize=14)
plt.xlabel("Predicted Genre", fontsize=12, labelpad=15)
plt.ylabel("True Genre", fontsize=12, labelpad=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(False)
plt.tight_layout()
plt.show()

# Print detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels, 
                           target_names=genre_labels, digits=3))

# Show class distribution
print("\nClass Distribution in Test Set:")
for i, genre in enumerate(genre_labels):
    count = sum(y_test == i)
    if count > 0:
        acc = accuracy_score(y_test[y_test == i], y_pred_labels[y_test == i])
        print(f"{genre:<20}: {acc:.2%} ({count} samples)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
#
# True Genre: Rock
# Predicted Genre: Rock
# Confidence: 86.09%
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
#        Experimental      0.775     0.787     0.781       127
#         Avant-Garde      0.922     0.799     0.856       149
#                Rock      0.860     0.843     0.851       153
#                Folk      0.742     0.737     0.740       156
#             Hip-Hop      0.826     0.877     0.850       146
#               Blues      0.897     0.819     0.856       149
#   Singer-Songwriter      0.724     0.819     0.768       160
#           Classical      0.844     0.910     0.876       167
#              Techno      0.898     0.854     0.875       144
#                Jazz      0.728     0.804     0.764       143
#        Reggae - Dub      0.882     0.889     0.885       126
#             Country      0.735     0.808     0.770       151
#               Metal      0.886     0.838     0.862       167
# Old-Time / Historic      0.939     0.908     0.923       152
#            New Wave      0.902     0.866     0.884       149
#             Novelty      0.938     0.859     0.897       142
#
#            accuracy                          0.839      2381
#           macro avg      0.844     0.839     0.840      2381
#        weighted avg      0.843     0.839     0.840      2381
#
#
# Class Distribution in Test Set:
# Experimental        : 78.74% (127 samples)
# Avant-Garde         : 79.87% (149 samples)
# Rock                : 84.31% (153 samples)
# Folk                : 73.72% (156 samples)
# Hip-Hop             : 87.67% (146 samples)
# Blues               : 81.88% (149 samples)
# Singer-Songwriter   : 81.88% (160 samples)
# Classical           : 91.02% (167 samples)
# Techno              : 85.42% (144 samples)
# Jazz                : 80.42% (143 samples)
# Reggae - Dub        : 88.89% (126 samples)
# Country             : 80.79% (151 samples)
# Metal               : 83.83% (167 samples)
# Old-Time / Historic : 90.79% (152 samples)
# New Wave            : 86.58% (149 samples)
# Novelty             : 85.92% (142 samples)

# %%
import json
import os
import math
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tqdm import tqdm
import json
import os
import math
import librosa

# %%
import pandas as pd

# Track counts per genre
genre_counts = {
'Experimental'           :7203,
'Avant-Garde'            :2931,
'Rock'                   :2229,
'Folk'                   :2177,
'Hip-Hop'                :2025,
'Blues'                   :662,
'Singer-Songwriter'       :654,
'Classical'               :563,
'Techno'                  :560,
'Jazz'                    :511,
'Reggae - Dub'            :297,
'Country'                 :293,
'Metal'                   :285,
'Old-Time / Historic'     :187,
'New Wave'                :176,
'Novelty'                  :87,
}

# Target number of tracks per genre
target_tracks = 100


# Calculate multiplier for each genre
multipliers = {genre: target_tracks / count for genre, count in genre_counts.items()}

# Display the result
multipliers_df = pd.DataFrame(list(multipliers.items()), columns=["Genre", "Multiplier"])
print(multipliers_df)
# Out:
#                   Genre  Multiplier
# 0          Experimental    0.013883
# 1           Avant-Garde    0.034118
# 2                  Rock    0.044863
# 3                  Folk    0.045935
# 4               Hip-Hop    0.049383
# 5                 Blues    0.151057
# 6     Singer-Songwriter    0.152905
# 7             Classical    0.177620
# 8                Techno    0.178571
# 9                  Jazz    0.195695
# 10         Reggae - Dub    0.336700
# 11              Country    0.341297
# 12                Metal    0.350877
# 13  Old-Time / Historic    0.534759
# 14             New Wave    0.568182
# 15              Novelty    1.149425
